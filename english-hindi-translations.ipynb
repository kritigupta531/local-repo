# %%
# !pip3 install indic-nlp-library
# Out:
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl.metadata (5.7 kB)
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.5.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.2.4)
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (8.2.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (0.21.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.19.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.32.4)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (25.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->indic-nlp-library) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2025.6.15)
# Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.7 MB/s eta 0:00:00
# Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Downloading sphinx_argparse-0.5.2-py3-none-any.whl (12 kB)
# Installing collected packages: morfessor, sphinx-argparse, indic-nlp-library
# Successfully installed indic-nlp-library-0.92 morfessor-2.0.6 sphinx-argparse-0.5.2

# %%
import pandas as pd
import numpy as np
from transformers import AutoTokenizer
import torch 
from indicnlp.tokenize import indic_tokenize

# %%
data=pd.read_csv("/kaggle/input/sample-dataset/Sentence pairs in English-Hindi - 2025-02-11.tsv",sep="\t",header=None,names=["SrcSent ID","SrcSent","DstSentID","DstSent"])

# %%
data.head()
# Out:
#    SrcSent ID                                  SrcSent  DstSentID  \
# 0        1282                       Muiriel is 20 now.     485968
# 1        1282                       Muiriel is 20 now.    2060319
# 2        1294  Education in this world disappoints me.     485564
# 3        1302                       That won't happen.    2060320
# 4        1308                              I miss you.    2060321
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
data.shape
# Out:
# (13182, 4)

# %%
data.drop(labels=[data.columns[0],data.columns[2]],axis=1,inplace=True)

# %%
data.head()
# Out:
#                                    SrcSent  \
# 0                       Muiriel is 20 now.
# 1                       Muiriel is 20 now.
# 2  Education in this world disappoints me.
# 3                       That won't happen.
# 4                              I miss you.
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
src_sent_tokenizer=AutoTokenizer.from_pretrained("google-T5/T5-base")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
data["SrcSent"]=data["SrcSent"].apply(lambda x: src_sent_tokenizer.tokenize(x))

# %%
data.head()
# Out:
#                                              SrcSent  \
# 0                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 1                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 2  [▁Education, ▁in, ▁this, ▁world, ▁disappoint, ...
# 3                    [▁That, ▁won, ', t, ▁happen, .]
# 4                               [▁I, ▁miss, ▁you, .]
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
data["DstSent"]=data["DstSent"].apply(lambda x: indic_tokenize.trivial_tokenize(x,lang="hi"))

# %%
data.head()
# Out:
#                                              SrcSent  \
# 0                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 1                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 2  [▁Education, ▁in, ▁this, ▁world, ▁disappoint, ...
# 3                    [▁That, ▁won, ', t, ▁happen, .]
# 4                               [▁I, ▁miss, ▁you, .]
#
#                                              DstSent
# 0        [म्यूरियल, अब, बीस, साल, की, हो, गई, है, ।]
# 1                [म्यूरियल, अब, बीस, साल, की, है, ।]
# 2  [मैं, इस, दुनिया, में, शिक्षा, पर, बहुत, निराश...
# 3                              [वैसा, नहीं, होगा, ।]
# 4              [मुझें, तुम्हारी, याद, आ, रही, है, ।]

# %%
data["SrcSent"]=data["SrcSent"].apply(src_sent_tokenizer.convert_tokens_to_ids)

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent
# 0        [म्यूरियल, अब, बीस, साल, की, हो, गई, है, ।]
# 1                [म्यूरियल, अब, बीस, साल, की, है, ।]
# 2  [मैं, इस, दुनिया, में, शिक्षा, पर, बहुत, निराश...
# 3                              [वैसा, नहीं, होगा, ।]
# 4              [मुझें, तुम्हारी, याद, आ, रही, है, ।]

# %%
Vs=src_sent_tokenizer.get_vocab()

# %%
Vs
# Out:
# {'▁9.': 5835,
#  '▁armor': 18750,
#  '▁legitimate': 12372,
#  'stimmung': 11822,
#  '▁majeur': 18541,
#  '▁ja': 2662,
#  'privileged': 23046,
#  '▁Thrones': 29344,
#  'mut': 4246,
#  '▁Idaho': 19546,
#  '▁hijack': 30968,
#  '▁Inspired': 22783,
#  '▁reel': 14495,
#  '▁prime': 3427,
#  'ACS': 26865,
#  '▁aspect': 2663,
#  '▁Walter': 13171,
#  '▁AND': 3430,
#  '▁Pel': 18773,
#  'uber': 14659,
#  'schw': 5472,
#  '▁customizable': 23834,
#  '2).': 15070,
#  '▁consume': 11037,
#  '▁bite': 9133,
#  '▁peculiar': 26460,
#  '▁diferenț': 28233,
#  '▁Emergency': 15118,
#  'taking': 14867,
#  '▁Doug': 19034,
#  '▁entirety': 26771,
#  '▁totodat': 26388,
#  '▁popular': 1012,
#  'municipiul': 30102,
#  '▁vânzări': 31129,
#  'shaw': 15622,
#  '▁[...]': 23296,
#  '▁compassion': 14555,
#  '▁hamper': 26395,
#  '▁unit': 1745,
#  '▁bills': 7200,
#  '▁Miller': 9429,
#  'pointing': 15989,
#  '▁ca': 212,
#  'WORLD': 30944,
#  'count': 13362,
#  'rison': 23790,
#  '▁diferenta': 28182,
#  'rruption': 27599,
#  'asse': 3974,
#  '▁Vel': 11670,
#  '▁displayed': 6099,
#  '▁stopped': 4910,
#  '▁footage': 13420,
#  '▁aventur': 24089,
#  '▁publicity': 23546,
#  '▁ruling': 12346,
#  '▁Package': 14815,
#  'keep': 20582,
#  '▁$2': 3771,
#  '▁energy': 827,
#  'rash': 12380,
#  '▁motivated': 11361,
#  '▁Brilliant': 27159,
#  '▁cone': 14075,
#  'östlich': 25311,
#  'user': 10041,
#  'rest': 6216,
#  '▁Yi': 14224,
#  '▁Joyce': 27121,
#  'over': 1890,
#  '▁Strategic': 20062,
#  'gesehen': 11139,
#  '▁treats': 11954,
#  '▁réclam': 28127,
#  'ân': 3398,
#  '▁hervor': 19292,
#  '▁lately': 12643,
#  '▁alegeri': 25856,
#  '▁follows': 6963,
#  'marin': 12181,
#  '▁nommé': 29491,
#  '▁strictly': 15154,
#  '▁combined': 3334,
#  '▁emblem': 26919,
#  '400,000': 31471,
#  'héros': 28126,
#  '▁Happi': 27171,
#  '▁early': 778,
#  'lent': 6987,
#  '▁correspondent': 25688,
#  '▁thieves': 31219,
#  '▁realm': 15854,
#  'risti': 22061,
#  '▁unsere': 1324,
#  '▁commande': 8746,
#  '▁ultima': 11422,
#  '▁activist': 20622,
#  '▁Alliance': 11529,
#  '▁browser': 3509,
#  '▁911': 23783,
#  'complete': 25288,
#  'villagers': 31101,
#  '▁Merry': 25107,
#  '▁Wisconsin': 10212,
#  '▁fapt': 2395,
#  'Luc': 11748,
#  'escaping': 31897,
#  'geht': 18439,
#  '▁Tele': 7338,
#  '▁airplane': 20527,
#  '▁intelege': 21918,
#  '▁Schlüssel': 22794,
#  '▁impeccable': 26449,
#  'cake': 13192,
#  '▁saturated': 25703,
#  '▁hometown': 22295,
#  '▁appearance': 3179,
#  '▁découvert': 28066,
#  'Mobile': 22162,
#  'companiile': 29680,
#  '▁Location': 10450,
#  'Associated': 26138,
#  '▁incep': 23352,
#  '▁fundraising': 13820,
#  'needed': 25797,
#  '▁célébr': 26456,
#  '▁offered': 1860,
#  'present': 12640,
#  '▁2004,': 16931,
#  '▁Welcome': 5242,
#  '▁hydraulic': 20320,
#  '▁juca': 15632,
#  '▁Albert': 11375,
#  'ulent': 16291,
#  'ffentlich': 24425,
#  '▁legislati': 24641,
#  '▁congratulations': 29138,
#  '▁comprehend': 21494,
#  '▁sécurisé': 27938,
#  '▁interiorul': 21544,
#  '▁salvation': 19995,
#  '▁extremely': 2033,
#  '▁Energie': 6901,
#  '▁Konzept': 15901,
#  '▁droite': 16872,
#  '▁Milwaukee': 21140,
#  '▁vârf': 29152,
#  '▁possède': 16865,
#  '▁drum': 5253,
#  'rac': 3738,
#  '▁have': 43,
#  '▁season': 774,
#  'jungen': 21000,
#  'ducted': 21336,
#  '▁cuir': 20352,
#  'wärts': 23974,
#  '▁Ash': 7153,
#  '<extra_id_4>': 32095,
#  'RAD': 21577,
#  '▁şedinţ': 28109,
#  '▁Siemens': 27124,
#  'anumite': 11903,
#  'tec': 5822,
#  '▁plague': 29230,
#  '09.': 12900,
#  '▁semifinal': 27504,
#  '▁feasibility': 28297,
#  'area': 498,
#  '▁Honda': 12886,
#  '▁zwei': 2352,
#  '▁transcript': 20146,
#  '▁mathematical': 18913,
#  '▁Journey': 20709,
#  'extending': 16878,
#  '▁consultant': 7792,
#  'minister': 17791,
#  '▁great': 248,
#  '▁complaints': 11244,
#  '▁mentor': 9380,
#  '▁mess': 8090,
#  '▁Guys': 9070,
#  'AUD': 22711,
#  'acre': 10610,
#  '▁Mor': 4574,
#  'gator': 19306,
#  '▁Clip': 17399,
#  '▁ferr': 25007,
#  '▁jaune': 22475,
#  '▁fell': 4728,
#  'clo': 3903,
#  '▁read': 608,
#  'éri': 5134,
#  '▁observations': 14181,
#  '▁engraving': 30957,
#  '▁Depend': 30718,
#  '▁stored': 5816,
#  '▁Yahoo': 15670,
#  '▁cea': 2511,
#  '▁părăs': 28836,
#  'räu': 14674,
#  '▁Football': 10929,
#  'Compania': 27067,
#  '▁încet': 23408,
#  '▁fragile': 18659,
#  '▁Investment': 9682,
#  '▁Anton': 14407,
#  '▁15%': 13914,
#  '▁pest': 6256,
#  '▁honeymoon': 27999,
#  '▁shot': 2538,
#  '▁stolen': 14244,
#  '▁cor': 4301,
#  '▁Resources': 10179,
#  'disc': 19315,
#  '▁Shaw': 15333,
#  '▁Lou': 11884,
#  '▁upgraded': 15490,
#  '▁cup': 4119,
#  'lösung': 15033,
#  'steigert': 31939,
#  'relates': 21679,
#  '▁prosperity': 21571,
#  'DOWN': 30828,
#  '▁contributed': 9859,
#  'VP': 11527,
#  '▁Kindergarten': 24758,
#  '▁pensii': 29246,
#  '▁Sammlung': 27049,
#  '▁Rock': 3120,
#  'mother': 21226,
#  '▁Stewart': 16496,
#  '▁consortium': 27754,
#  '▁Winter': 4272,
#  '▁color': 945,
#  'vascular': 15100,
#  '▁scallop': 31140,
#  '▁scrutiny': 25778,
#  'ти': 18352,
#  'TRI': 16840,
#  'action': 4787,
#  '▁tragedy': 18914,
#  '▁Teilnehmer': 10957,
#  '▁belong': 13000,
#  'ucked': 15318,
#  '▁peek': 20584,
#  '▁Giving': 22643,
#  'circulating': 30715,
#  'iola': 23578,
#  '▁Sp': 2526,
#  '▁ashamed': 30119,
#  '▁immigrants': 16096,
#  '▁intuition': 26207,
#  '▁Along': 8529,
#  'trade': 16628,
#  '▁robust': 6268,
#  '▁Cause': 23142,
#  '▁grind': 20743,
#  '▁soit': 3091,
#  '▁eyes': 2053,
#  '▁bonuses': 17489,
#  '▁definitive': 20374,
#  'vent': 2169,
#  'gastrointestinal': 30282,
#  'SL': 5629,
#  '▁Scrap': 27962,
#  '▁erlaubt': 23437,
#  '▁roughly': 10209,
#  '▁extended': 4760,
#  'pal': 6459,
#  '▁tart': 14981,
#  '▁soleil': 15542,
#  '▁Teddy': 30146,
#  '▁shake': 8944,
#  'évaluation': 22389,
#  '850': 17246,
#  '▁ideologi': 31001,
#  '▁just': 131,
#  '▁decision': 1357,
#  '▁Kashmir': 26869,
#  '▁footprint': 16630,
#  '▁properly': 3085,
#  '▁ainsi': 2236,
#  '▁Los': 3144,
#  'itude': 20341,
#  '▁zis': 15396,
#  '▁utilizatorilor': 27985,
#  '▁dropping': 14087,
#  '▁160': 11321,
#  '▁investor': 12024,
#  '▁Vinyl': 22283,
#  '▁mono': 7414,
#  '▁vielfältig': 23404,
#  'campus': 25532,
#  '▁greatly': 6891,
#  '▁shortcomings': 31221,
#  '▁markets': 3212,
#  '▁apă': 9530,
#  '▁violat': 27857,
#  '▁6': 431,
#  '▁awarded': 5539,
#  '2.9': 27297,
#  'tefan': 24018,
#  '▁curl': 18322,
#  '▁mill': 3293,
#  '▁United': 907,
#  '▁urmă': 9371,
#  '▁Fire': 3655,
#  '▁List': 6792,
#  'flam': 10980,
#  'hä': 10926,
#  'schiff': 26453,
#  'unsecured': 31605,
#  '▁800': 8640,
#  '▁einzigartige': 23145,
#  '▁sus': 4324,
#  '▁curb': 16110,
#  'Dedicated': 30348,
#  '▁objective': 5997,
#  'Stunning': 29742,
#  '▁renal': 23328,
#  '▁politically': 22937,
#  '▁External': 26241,
#  '▁not': 59,
#  '▁Province': 19573,
#  '▁clôtur': 30795,
#  '▁NHS': 17804,
#  '▁Belt': 18845,
#  '▁travelling': 10238,
#  '▁pilot': 4487,
#  '▁Highlight': 16388,
#  '▁imprisonment': 30823,
#  'especially': 15616,
#  'oasă': 10492,
#  'AM': 4815,
#  '▁bolnav': 25170,
#  '▁puck': 28992,
#  '▁programs': 1356,
#  'ația': 8110,
#  'haltung': 12706,
#  '▁confusing': 15266,
#  '▁Wohl': 24535,
#  '▁vague': 15986,
#  'published': 23841,
#  '▁absent': 14101,
#  '▁shaft': 15843,
#  'dra': 3515,
#  '▁kombiniert': 29343,
#  '▁näher': 19875,
#  '▁Nachricht': 19233,
#  '▁vorhanden': 12819,
#  'CE': 4770,
#  '▁domestic': 4422,
#  '▁WA': 7896,
#  '▁continues': 3256,
#  '▁Mount': 7964,
#  '▁mutant': 26569,
#  '▁disciplin': 30741,
#  '▁Tor': 3794,
#  '▁Rental': 14157,
#  '▁disque': 23845,
#  '▁(6': 11372,
#  '▁Syracuse': 30482,
#  '▁Forum': 5841,
#  'kie': 11390,
#  '▁exkl': 27506,
#  'länge': 22467,
#  '▁carbohydrates': 26883,
#  '▁Geschichte': 7911,
#  '▁contribution': 6275,
#  '▁K': 480,
#  '▁brin': 25799,
#  'frame': 11415,
#  'athlet': 26170,
#  'org': 1677,
#  '▁notion': 9347,
#  '▁dwell': 22231,
#  '▁ţară': 22457,
#  '▁Naţional': 14887,
#  '▁Notebook': 29125,
#  '▁Sacramento': 22178,
#  'entretien': 14048,
#  '▁Claus': 22021,
#  '▁Jag': 21520,
#  '▁impart': 15950,
#  '▁Cherry': 21743,
#  '▁Ver': 781,
#  '▁Dumpster': 12101,
#  '▁property': 785,
#  '▁transcend': 23080,
#  'Das': 17266,
#  '▁als': 501,
#  '▁Farb': 15452,
#  'dividing': 29111,
#  '▁Bring': 10267,
#  'aux': 1724,
#  '2013': 11138,
#  '▁accelerate': 16845,
#  'peri': 4267,
#  'sti': 2248,
#  '▁eggplant': 30898,
#  '▁then': 258,
#  '▁constant': 3917,
#  'dad': 14677,
#  '▁Academy': 4702,
#  '▁monde': 2921,
#  'ergebnisse': 21406,
#  'figuring': 18765,
#  '▁greatest': 4016,
#  'gefahren': 26997,
#  '▁activitatea': 13493,
#  '▁Buddy': 27289,
#  'eng': 4606,
#  '▁marque': 6971,
#  'woman': 15893,
#  '▁businesses': 1623,
#  'veţi': 19918,
#  '▁tumor': 8985,
#  '▁Baseball': 22398,
#  'Direct': 23620,
#  '▁glory': 12582,
#  'țional': 12890,
#  '▁garde': 15408,
#  'Software': 29944,
#  '▁Erfahrung': 11123,
#  '▁corporation': 11861,
#  '▁remaining': 4080,
#  '▁shift': 4108,
#  '▁flap': 23050,
#  '▁unfamiliar': 24108,
#  'ified': 3676,
#  'ajute': 26127,
#  'Cal': 14318,
#  '........': 19794,
#  'gebrochen': 30563,
#  '▁Betracht': 26584,
#  '▁Push': 20761,
#  'ându': 8594,
#  '▁făc': 18435,
#  '▁Living': 5753,
#  '▁Ecuador': 25101,
#  '▁mandat': 15579,
#  'aus': 2064,
#  '▁Hernandez': 31765,
#  '▁labour': 12568,
#  '▁Music': 3057,
#  '▁Verfahren': 18130,
#  '▁Berliner': 22601,
#  '▁cleansing': 21935,
#  '▁isolation': 15997,
#  'kim': 19754,
#  'ön': 11431,
#  'oase': 4722,
#  'alternating': 30859,
#  'kamera': 28867,
#  'Point': 22512,
#  'cine': 14760,
#  '▁diving': 15680,
#  '▁pret': 7140,
#  '▁watching': 3355,
#  '▁Bob': 5762,
#  '2.': 4416,
#  'adorned': 29532,
#  '▁barb': 9935,
#  '▁Pond': 24204,
#  '▁Ils': 7503,
#  '400': 5548,
#  '▁CV': 10430,
#  '▁oasis': 30429,
#  '▁geprüft': 29322,
#  'including': 5751,
#  'Präsident': 20962,
#  '▁Cod': 10285,
#  'ENCE': 22614,
#  'dded': 15748,
#  '▁pipes': 14874,
#  '▁Kräfte': 31436,
#  '800': 6192,
#  '▁Gebrauch': 20397,
#  'olph': 23589,
#  'tial': 10646,
#  'giving': 14259,
#  'zahl': 8117,
#  '▁fotografi': 14624,
#  'oph': 10775,
#  '▁Außen': 15749,
#  '▁strat': 10133,
#  '▁driving': 2191,
#  '▁Butler': 21742,
#  '▁losing': 5489,
#  '▁là': 5381,
#  '▁Extrem': 20355,
#  '▁Privat': 16084,
#  '▁Cape': 9702,
#  'tură': 12994,
#  '▁representatives': 8675,
#  '▁considerat': 14479,
#  '▁munca': 11777,
#  '▁projected': 16037,
#  '▁fellow': 4999,
#  '▁Discover': 10793,
#  '<extra_id_89>': 32010,
#  '▁Fellow': 16344,
#  '▁Settlement': 31044,
#  '▁esențial': 30667,
#  '▁partagé': 26613,
#  'frac': 9880,
#  '▁highway': 10367,
#  '▁funcți': 21278,
#  '▁persistence': 29486,
#  'arth': 10702,
#  'scale': 6649,
#  'exception': 26286,
#  'pai': 13585,
#  'chip': 17362,
#  '▁however': 983,
#  '▁smile': 3993,
#  '▁Fly': 8223,
#  'nuit': 11201,
#  '▁engagiert': 28174,
#  '▁Kent': 14599,
#  '▁Telekom': 30068,
#  'mination': 14484,
#  '▁day': 239,
#  'wort': 8129,
#  '▁familiar': 3324,
#  '▁Hood': 19804,
#  '▁Link': 7505,
#  'stand': 2976,
#  'ifiant': 20172,
#  '▁Franchise': 30347,
#  '▁District': 3570,
#  '▁who': 113,
#  '▁interim': 20003,
#  'url': 16137,
#  '▁yeah': 17945,
#  '▁sign': 1320,
#  '▁tide': 19235,
#  '▁geographical': 20187,
#  '▁quasi': 16172,
#  'purchase': 29446,
#  '▁tineri': 14534,
#  '▁deaths': 14319,
#  '▁ST': 5097,
#  '▁CFR': 26257,
#  'eller': 9670,
#  'vru': 23178,
#  '▁inclusion': 11980,
#  '▁bladder': 26673,
#  '▁beliefs': 11393,
#  'ffe': 7398,
#  '▁mici': 6148,
#  '▁mentally': 19367,
#  '▁Kiel': 30326,
#  'itorul': 21570,
#  '▁télécharger': 25884,
#  '▁factor': 2945,
#  '▁Guess': 28291,
#  '▁measurement': 9753,
#  '▁avenue': 18836,
#  '▁Dis': 2678,
#  '▁Pat': 5192,
#  '▁notwendig': 12684,
#  '▁disable': 20597,
#  '▁Scha': 11450,
#  '▁door': 1365,
#  '▁médaill': 31594,
#  'erton': 24471,
#  '▁Mazda': 24730,
#  '▁Bubble': 30153,
#  '▁blood': 1717,
#  'sign': 6732,
#  '▁prostate': 25567,
#  '▁recap': 22591,
#  '▁copies': 8167,
#  'bon': 5407,
#  '▁Hall': 2501,
#  '▁créateur': 29931,
#  '▁sânge': 20998,
#  '▁winners': 8969,
#  'hugs': 31081,
#  '▁probable': 23093,
#  'Sculpt': 26637,
#  '▁după': 2322,
#  'deli': 12460,
#  '▁curent': 16389,
#  'deluxe': 27747,
#  '▁offen': 10883,
#  'gone': 16967,
#  '▁violation': 12374,
#  '▁Dom': 10576,
#  'trip': 14192,
#  '▁caught': 4682,
#  '▁gouvernement': 11382,
#  'SIL': 26525,
#  'czy': 21955,
#  '▁Preservation': 31567,
#  '▁crema': 15274,
#  '▁(7': 13649,
#  '▁achiziţi': 29536,
#  '▁statistic': 19720,
#  'Sie': 23357,
#  '▁records': 3187,
#  '▁grant': 5334,
#  'leiten': 23252,
#  '„': 25526,
#  'vin': 2494,
#  '▁Reviews': 16305,
#  '▁$30': 19106,
#  'obtainable': 31723,
#  '▁things': 378,
#  '▁2012.': 7033,
#  'museum': 25581,
#  '▁1969': 17185,
#  '▁Ambassador': 20432,
#  '▁price': 594,
#  '▁liabilities': 25468,
#  'quit': 10073,
#  '▁greenhouse': 17572,
#  '▁helped': 2139,
#  '▁suspect': 6220,
#  'amerikanische': 23384,
#  'Increasing': 31372,
#  '520': 25356,
#  '▁Chor': 17531,
#  '▁Hand': 2263,
#  '▁religi': 13806,
#  '▁Evolution': 21625,
#  '▁nominee': 21077,
#  '▁Walmart': 20723,
#  'gé': 4020,
#  '▁Benefici': 30570,
#  '▁emerging': 7821,
#  '▁Java': 10318,
#  '▁Fred': 12264,
#  '▁Firma': 14533,
#  'quality': 4497,
#  '▁bubble': 11144,
#  '▁Split': 23575,
#  '▁Edward': 8200,
#  '▁listed': 2616,
#  'coming': 10622,
#  '▁Logo': 15327,
#  '▁react': 8922,
#  '3.8': 26195,
#  '▁reconcil': 27679,
#  '▁Tra': 3083,
#  'Interested': 21466,
#  '▁Level': 7166,
#  '▁Kill': 14450,
#  '▁concern': 2410,
#  '▁Mack': 19155,
#  '▁Portuguese': 21076,
#  'special': 17434,
#  '▁dégag': 29001,
#  '▁static': 14491,
#  '▁Noise': 28964,
#  '▁împiedic': 31043,
#  '▁rope': 13888,
#  '▁carton': 17676,
#  '▁sculpture': 10519,
#  'bury': 7165,
#  '▁Ltd': 3937,
#  '▁younger': 5868,
#  '▁Epic': 24692,
#  'ure': 1462,
#  '▁initiative': 6121,
#  '▁prints': 11384,
#  'rechtliche': 18785,
#  'num': 5525,
#  '▁Flint': 29612,
#  '▁crédit': 17923,
#  '▁Measure': 16317,
#  '▁azi': 11470,
#  'effekt': 27112,
#  'resident': 15704,
#  '▁begeistert': 21652,
#  '45': 2128,
#  '▁comfort': 2115,
#  '▁clase': 25062,
#  '▁sleep': 2085,
#  '▁relaţi': 23294,
#  '▁folosesc': 17042,
#  'avez': 3618,
#  'Kü': 20221,
#  '▁unfortunately': 12050,
#  '▁traits': 16843,
#  '▁Pie': 11591,
#  '▁hobbies': 27781,
#  '▁Bauch': 27671,
#  '▁publicly': 11652,
#  '▁Nouvelle': 25671,
#  'Bra': 18304,
#  '▁catalogue': 14978,
#  'Known': 26176,
#  'cône': 30799,
#  'catching': 11907,
#  '▁axle': 28888,
#  '▁mercredi': 20903,
#  '▁diet': 3178,
#  '▁preuve': 20287,
#  '▁Eisen': 19027,
#  'probably': 31106,
#  '▁fabricant': 20027,
#  '▁schlecht': 12846,
#  'mètre': 20572,
#  '▁ZIP': 25844,
#  '▁economist': 20163,
#  '▁lawyer': 6297,
#  '▁Müller': 25391,
#  '▁sugar': 2656,
#  '▁discussing': 12104,
#  '▁smoothly': 14000,
#  '▁dumneavoastră': 15078,
#  '▁aircraft': 6442,
#  '▁praying': 20877,
#  'Sollte': 15900,
#  'aliment': 8972,
#  '▁wrapping': 23342,
#  'explorer': 20901,
#  '▁Mechanism': 31529,
#  'upper': 15689,
#  '▁genutzt': 15149,
#  '▁indicate': 6360,
#  '▁Flash': 9497,
#  'Usually': 12576,
#  '▁Point': 4564,
#  '▁invention': 8936,
#  '▁Ministerul': 17036,
#  '▁fraud': 7712,
#  '<extra_id_22>': 32077,
#  '▁icon': 6705,
#  'folosirea': 23452,
#  '▁marathon': 17625,
#  '▁besondere': 7537,
#  '▁shout': 14314,
#  '▁residents': 2797,
#  '▁Amy': 13349,
#  '▁Nu': 1174,
#  '▁Parchet': 31717,
#  '▁lutte': 19817,
#  '▁Herbst': 21073,
#  '▁Anfang': 11302,
#  'dar': 3439,
#  '▁Around': 16140,
#  '▁jpl': 31719,
#  '▁Munte': 29523,
#  '▁Environmental': 9185,
#  '138': 22744,
#  '▁selten': 16519,
#  'issent': 10924,
#  '▁special': 534,
#  '▁You': 148,
#  '▁reconnaît': 26492,
#  '▁Gleich': 18335,
#  '▁Sara': 12969,
#  'nähe': 27334,
#  'COM': 6657,
#  '▁Einkauf': 21040,
#  '▁Fantastic': 21737,
#  '▁crane': 25126,
#  'Occident': 30583,
#  '▁elegant': 3865,
#  '▁întrerup': 31888,
#  'unified': 22927,
#  'versorgung': 24479,
#  'igh': 9031,
#  'January': 30404,
#  '2.000': 26756,
#  'JA': 13853,
#  '▁Hire': 19377,
#  '▁récent': 21587,
#  '▁Seven': 13065,
#  '▁Sache': 18791,
#  '▁Pandora': 31490,
#  'founded': 23329,
#  '▁Hot': 5396,
#  '▁offiziell': 26082,
#  '▁decoration': 11649,
#  '▁claw': 27331,
#  'Alex': 27280,
#  '▁aplica': 10589,
#  '▁Automotive': 20378,
#  'iding': 12469,
#  '▁winning': 3447,
#  'Daddy': 26306,
#  'U': 1265,
#  'ité': 1257,
#  '▁brown': 4216,
#  'ity': 485,
#  '▁foil': 15779,
#  'ected': 7633,
#  'igan': 12588,
#  'École': 31721,
#  '▁level': 593,
#  '▁internet': 1396,
#  '▁Dar': 1920,
#  '▁INFORMATION': 28338,
#  'troph': 14618,
#  '▁9': 668,
#  '▁présidentielle': 29128,
#  'ergebnis': 30942,
#  'legung': 19123,
#  'tral': 8792,
#  '▁găsit': 18997,
#  'Especially': 14232,
#  '▁jours': 4520,
#  '▁potatoes': 11076,
#  '▁bliss': 26078,
#  '▁produit': 5789,
#  '▁următoare': 25358,
#  '▁Gi': 3156,
#  '▁scandal': 14605,
#  '▁Wash': 12429,
#  '▁dignity': 21377,
#  'onal': 9533,
#  '▁Condo': 21723,
#  '▁State': 1015,
#  'adapt': 13376,
#  '▁access': 592,
#  '▁Trevor': 29352,
#  'Bar': 14851,
#  '▁decide': 2204,
#  '30,000': 17093,
#  '▁nothing': 1327,
#  '▁NEED': 28969,
#  '▁fuzzy': 31089,
#  'NT': 7359,
#  '35': 2469,
#  'geben': 6186,
#  'urgence': 16786,
#  '▁Ausland': 22056,
#  '▁reflective': 22891,
#  '▁Current': 12892,
#  '▁reasonable': 4360,
#  '▁Giveaway': 30663,
#  '▁Not': 933,
#  '▁tint': 21970,
#  '▁wiring': 8997,
#  '▁kennenlernen': 31844,
#  '▁wider': 6281,
#  'Fraktion': 31002,
#  '▁scratches': 25957,
#  '▁eradicate': 30896,
#  '▁aboard': 21392,
#  '▁consider': 1099,
#  '▁wrapped': 11972,
#  'erlebnis': 28336,
#  '▁ministère': 24803,
#  'analyzing': 19175,
#  'ME': 4369,
#  '▁Eindruck': 24000,
#  '▁affect': 2603,
#  '▁Arrow': 25810,
#  '▁Analytics': 13926,
#  '▁function': 1681,
#  'bur': 5808,
#  'Where': 25217,
#  '▁Ph': 3657,
#  'lite': 6311,
#  '▁drei': 4052,
#  '▁teams': 2323,
#  '▁Side': 9466,
#  'euil': 16561,
#  '▁abgeschlossen': 22846,
#  '▁inclu': 12507,
#  'idio': 19916,
#  '▁Dip': 23177,
#  '▁Gem': 14493,
#  '▁Meditation': 26328,
#  'manned': 28556,
#  '▁3/4': 16672,
#  '▁anticipat': 27538,
#  '▁unele': 9482,
#  '▁pants': 12792,
#  '▁afecteaz': 28251,
#  '▁rainforest': 28355,
#  '▁skiing': 18483,
#  '▁navigate': 7939,
#  'friendly': 4905,
#  'bah': 17670,
#  '▁sustained': 14399,
#  '▁Sub': 3325,
#  'rented': 20907,
#  '▁cladiri': 30457,
#  'ôme': 20023,
#  '▁Tehran': 31238,
#  'auftrag': 26157,
#  '▁feat': 20906,
#  '▁leaf': 8384,
#  'nterdisciplinary': 25503,
#  '▁finger': 8425,
#  'ander': 11849,
#  'épisode': 24349,
#  '▁cheer': 11288,
#  '▁wunderschöne': 23284,
#  '▁Sk': 6458,
#  '▁physiological': 26574,
#  'cumva': 25455,
#  'lene': 14205,
#  '▁Anschluss': 18468,
#  '▁turf': 23802,
#  '▁etwas': 2800,
#  '▁langfristig': 25805,
#  '▁erzählt': 22016,
#  '▁Chiar': 12995,
#  '▁growth': 1170,
#  '▁cunosc': 22135,
#  'schätze': 23388,
#  'lake': 16948,
#  '▁Lunch': 20516,
#  'Print': 28592,
#  'Set': 17175,
#  'apei': 22348,
#  'ubb': 21207,
#  '▁Schwangerschaft': 31547,
#  '▁clinique': 29065,
#  '▁persoane': 3748,
#  '▁homosexual': 31330,
#  '159': 27904,
#  '▁caracter': 10560,
#  'ffel': 16387,
#  'itinéraire': 31923,
#  '▁țar': 28111,
#  'rav': 11852,
#  'haben': 16043,
#  '▁stamp': 7334,
#  '▁bumbac': 31128,
#  '▁bold': 8197,
#  '▁Outstanding': 27178,
#  '▁Lauf': 9450,
#  '▁Erweiterung': 30346,
#  '▁Flugzeug': 30702,
#  '▁neuen': 3988,
#  '▁barre': 18595,
#  '▁Flip': 21599,
#  '▁Var': 10137,
#  '▁Too': 9647,
#  '▁genannt': 19862,
#  '▁sort': 1843,
#  'fahrer': 20531,
#  '▁Market': 3611,
#  '▁Dock': 22314,
#  '▁fiecare': 2631,
#  'trap': 16081,
#  '▁durable': 5366,
#  '▁chocolat': 21549,
#  '▁ehrlich': 29204,
#  'kli': 20529,
#  '▁investigated': 18277,
#  '▁réalis': 14211,
#  '▁epic': 12953,
#  '5-2': 24279,
#  '▁significant': 1516,
#  'évolution': 13904,
#  '▁they': 79,
#  '▁Exemplar': 31402,
#  '▁Business': 1769,
#  '▁spark': 13233,
#  '▁rarely': 8207,
#  'compania': 17545,
#  '▁1/2"': 23562,
#  '▁fave': 21343,
#  '▁wounded': 21372,
#  '▁dép': 16257,
#  'related': 3897,
#  '▁countries': 1440,
#  '▁Danny': 19445,
#  '▁învăța': 27589,
#  'curi': 9659,
#  '▁somehow': 9296,
#  '▁Auto': 2040,
#  'hyp': 13397,
#  '▁overseas': 10055,
#  '▁baked': 13635,
#  'ette': 1954,
#  'peaks': 25399,
#  '▁pregăt': 18390,
#  'level': 4563,
#  '▁8:30': 23899,
#  '▁hetero': 26481,
#  '▁incercat': 22809,
#  '▁transmis': 12454,
#  'ucun': 22838,
#  'outhwestern': 31380,
#  '▁particulier': 8866,
#  '▁exhaustive': 29124,
#  'eaza': 1802,
#  'vol': 4571,
#  '▁praise': 11308,
#  '▁points': 979,
#  '▁culturelle': 24413,
#  '▁Weekly': 22297,
#  '▁Portsmouth': 31696,
#  'KO': 12725,
#  '▁Craig': 12870,
#  '▁Persian': 25518,
#  '▁Christopher': 14702,
#  '▁Spitze': 17894,
#  '▁peanut': 14998,
#  ...}

# %%
len(Vs)
# Out:
# 32100

# %%
hindi_vocab=set()

for tokenized_hindi_sent in data["DstSent"]:
    hindi_vocab.update(tokenized_hindi_sent)

# %%
hindi_vocab
# Out:
# {'ग़रीब',
#  'तीसरा',
#  'सौन्\u200dदर्य',
#  'बेची',
#  'अंतरात्मा',
#  'रोडिका',
#  'बताता',
#  'छुट्टे',
#  'विवेकी',
#  'जिमखाने',
#  'व्यर्थ',
#  'पुर्त्तगाल',
#  'कोरिया',
#  'बीजिंग',
#  'फटाफट',
#  'दूँगा',
#  'फ़ेसबुक',
#  'भिखारियों',
#  'सदमा',
#  'बेवकूफ़',
#  'दिशा',
#  'घर',
#  'लिपटा',
#  'खिलौना',
#  'चेतावनी',
#  'बुझता',
#  'असुविधा',
#  'बोतल',
#  'अंधा',
#  'अध्ययन',
#  'बनातें',
#  'निकालिए',
#  'लौटूँगा',
#  'स्वच्छ',
#  'वेल्स',
#  'बकरियों',
#  'सवारी',
#  'शोर',
#  'खरिद',
#  'सालगिरह',
#  'सवार',
#  'भागें',
#  'बैठा',
#  'उपनाम',
#  'यार',
#  'हटो',
#  'गरम',
#  'अक़सर',
#  'सूट',
#  'यामादा',
#  'फार्म',
#  'व्यक्ती',
#  'पेनसिल',
#  'तम्बाकू',
#  'ऊँचा',
#  'मलेरिया',
#  'कप्तान',
#  'फिसल',
#  'वो',
#  'सिखाए',
#  'ख़त्म',
#  'बदल',
#  'बेचैनी',
#  'सिक्कों',
#  'मौज',
#  'होमोसेक्सुअल',
#  'दमिश्क',
#  'कोशिश',
#  'निरोध',
#  'दंभी',
#  'मानने',
#  'कायदे',
#  'तए',
#  'या',
#  'कहूं',
#  'चुके',
#  'स्वर्ग',
#  'रेलगाड़ी',
#  'फ़ायदा',
#  'निराश',
#  'पूछूँगा',
#  'वंचित',
#  'जोन',
#  'जुलतीं',
#  'बयान',
#  'अनुवाद',
#  'रंडी',
#  'गाना',
#  'झूठा',
#  'मज़ेदार',
#  'सुपर',
#  'मालुम',
#  'उसकी',
#  'सकतें',
#  'गर्दन',
#  'सुशी',
#  'ऐन',
#  'बगुले',
#  'चलाया',
#  'सूझ',
#  'जुलती',
#  'ढूँढो',
#  'घड़ी',
#  'सिद्धांत',
#  'पिघलेगी',
#  'बतख़',
#  'त्रुटियाँ',
#  'खेद',
#  'पत्थर',
#  'चोद',
#  'अकेली',
#  'रोज़ी',
#  'सुन',
#  'ड्रुक',
#  'स्काटिश',
#  'डरा',
#  'धुलवानीं',
#  'अपमानजनक',
#  'मत',
#  'ईसप',
#  'थप्पड़',
#  'टांगें',
#  'मंज़िल',
#  'पहुँचाई',
#  'तज़ुर्बे',
#  'पट्टी',
#  'स्कीर',
#  'चाहतीं',
#  'नाज़ी',
#  'जानते',
#  'शिकागो',
#  'दीमक',
#  'सीरिया',
#  'भूमध्य',
#  'क्रीम',
#  'कोशीश',
#  'बताउँगी',
#  'लिए',
#  'दवाइयां',
#  'छीन',
#  'स्तुति',
#  'बिस्तर',
#  'वृषभ',
#  'नाभिकीय',
#  'अफ़वाह',
#  'समझती',
#  'खत',
#  'पकाया',
#  'ख़ूब',
#  'फॉन्ट',
#  'नताशा',
#  'आए',
#  'प्रदर्शन',
#  'चूमने',
#  'अपनाएं',
#  'जाऊं',
#  '१६३६',
#  'डाक्टर',
#  'इनका',
#  'इतिहासकार',
#  'मूठ',
#  'नैनसी',
#  'बह',
#  'जानबूझकर',
#  'पूंछ',
#  'डचेस',
#  'पसंदीदा',
#  'आपका',
#  'डरते',
#  'बहरीन',
#  'बोल',
#  'एओस्तेराइख़',
#  'किन्तु',
#  'बहनें',
#  'चाहेंगी',
#  'दरवाजे',
#  'आँखें',
#  'घिसे',
#  'ओपनर',
#  'हिलो',
#  'फ़सल',
#  'घुसा',
#  'पैरीस',
#  'रोज़ाना',
#  'रोज़',
#  'साफ़',
#  'बेल्जियाई',
#  'प्रसिद्ध',
#  'गी',
#  'इलाक़ा',
#  'निकलने',
#  'समझाई',
#  'सवाल',
#  'धमाके',
#  'सावन',
#  'परिस्तिथि',
#  'निपुण',
#  'रक्त',
#  'एस',
#  'महिलाओं',
#  'दिवालिया',
#  'नज़्म',
#  'दिवाई',
#  'व्याप्त',
#  'कबाड़',
#  'सिक्का',
#  'प्रदूषण',
#  'हस्तमैथुन',
#  'शराबख़ाना',
#  'कमर',
#  'पतलून',
#  'सपने',
#  'कक्ष',
#  'सफ़ल',
#  'गुजरात',
#  'हस्पताल',
#  'समिति',
#  'भरे',
#  'लुसी',
#  'भौंकने',
#  'टिकती',
#  'हाँग',
#  'थम',
#  'मोटे',
#  'पराकाष्ठा',
#  'तीर',
#  'पीया',
#  'आयेगा',
#  'लौटें',
#  'घूमफिरकर',
#  'वदीयत',
#  'अन्तरात्मा',
#  'समझाया',
#  'लाती',
#  'कोमा',
#  'डिक्की',
#  'इन्टरनेट',
#  'रिमोट',
#  'दूँगी',
#  'द',
#  '२०१३',
#  'चाकलेट',
#  '१९७९',
#  'ज़िद्दी',
#  'धूल',
#  'करुँगी',
#  'डिंग',
#  'वाले',
#  'सर्व',
#  'से',
#  'हालांकि',
#  'अनुभूति',
#  'नेटफ़्लिक्स',
#  'भेजा',
#  'चलोगे',
#  'धत्',
#  'क़ैदी',
#  'आतंक',
#  'तापमान',
#  'खतरा',
#  'भुला',
#  'संक्षिप्त',
#  'सकें',
#  'पाकिस्तान',
#  'फ़्रांस',
#  'केवल',
#  'उस',
#  'पंथ',
#  'पड़ोस',
#  'किताबें',
#  'सोवियत',
#  'गलतियां',
#  'मिस्र',
#  'ओबोन',
#  'थोडी',
#  'बहुमत',
#  'मेन्नाद',
#  'बर्फ',
#  'जानो',
#  'आके',
#  'संरक्षण',
#  'नारिता',
#  'सोकर',
#  'आखरी',
#  'कबार',
#  'भेजने',
#  'कीव',
#  'उत्तेजित',
#  'बिज्जू',
#  'बनाओगे',
#  'हुमायून',
#  'टैबलेट',
#  'माफी',
#  'बढ़ी',
#  '?',
#  'खट्टा',
#  'गोलीबारी',
#  'सक्रिय',
#  'फैलाये',
#  'केल्टिक',
#  'करुंगा',
#  'स्कैनर',
#  'व्यक्त',
#  'थोडे',
#  'ईनाम',
#  'सेवाओं',
#  'टॅाम',
#  'धीरे',
#  'बाढ़',
#  'क़ुतुब',
#  'ड्यूटी',
#  'भरोसेमंद',
#  'फ़िदा',
#  'कंजूस',
#  'क्रूर',
#  'फ़िल्में',
#  'दीवालिया',
#  'जीभ',
#  'लूसिया',
#  'बड़ी',
#  'अखबारों',
#  'आयात',
#  'मित्र',
#  'बुझाया',
#  'छाता',
#  'हिस्से',
#  'भूलना',
#  'बजाई',
#  'लेलिया',
#  'अक्साई',
#  'परख',
#  'कल्पना',
#  'खोल',
#  'गुम',
#  'क़ीमत',
#  'लौटते',
#  'इनके',
#  'दिल',
#  'अरबी',
#  'शिशु',
#  'जीते',
#  'भागते',
#  'ला',
#  'नाइट',
#  'उपलब्ध',
#  'ज़बान',
#  'भूत',
#  'धीमी',
#  'करनीं',
#  'परिवार',
#  'निकाला',
#  'स्टेट',
#  'वैश्विक',
#  'लानत',
#  'कोकोनट',
#  'डैन',
#  'छोड़ो',
#  'डोमिनिकाना',
#  'विस्फोटो',
#  'गौल्फ़',
#  'बड़ा',
#  'जापान',
#  'राजधानीयां',
#  'उसको',
#  'सिगार',
#  'अक्टूबर',
#  'पंख',
#  'जानवर',
#  'छपेगी',
#  'फिराया',
#  'हटा',
#  '११९',
#  'ज़िरी',
#  'पुर्तगाल',
#  'लिंकन',
#  'देखतीं',
#  'ऑफिसर',
#  'बरी',
#  'कही',
#  'समझाएं',
#  'बेआराम',
#  'प्रोसेसर',
#  'हास्यस्पद',
#  'यरुशलम',
#  'बाइकाल',
#  'होगे',
#  '१९५७',
#  'मूर्ख',
#  'सम्पर्क',
#  '३०',
#  'सेहत',
#  'तरक़ीब',
#  'दूत',
#  'शिक्षा',
#  'सोचना',
#  'स्पोर्ट्स',
#  'दुष्ट',
#  'चाहें',
#  'अक्सर',
#  'बुआ',
#  'इमारतें',
#  'निभाना',
#  'गुड',
#  'चतुर',
#  'यूनानी',
#  'भाईचारे',
#  'टुकड़ों',
#  'तिरंगा',
#  'चलती',
#  'बिल्ले',
#  'गयें',
#  '१९९०',
#  'भरना',
#  'सीखते',
#  'पिलाओ',
#  'ये',
#  'तौलिए',
#  'सुँघाई',
#  'छोटे',
#  'निकला',
#  'जलने',
#  'जेठ',
#  'खतम',
#  'प्रातःकाल',
#  'चीनी',
#  'पार्सल',
#  'लाईं',
#  'विघटित',
#  'रेल',
#  'अंडा',
#  'चीज़ों',
#  'कामकाज',
#  'ऑनलाइन',
#  'रोक',
#  'प्रस्थापित',
#  'खुशखबरी',
#  'लाऊँगी',
#  'मचाओ',
#  'वैध',
#  'ख़त',
#  'सयाने',
#  'भागे',
#  'जुट',
#  'झगड़ा',
#  'बार्सेलोना',
#  'प्रात',
#  'टॉब',
#  'ज़िन्दगी',
#  'उसे',
#  'दिली',
#  'गलियारा',
#  'मामा',
#  'करीं',
#  'जॉगिंग',
#  'वस्\u200dतु',
#  'कुछ',
#  'चमक',
#  'दीजिएगा',
#  'औरडर',
#  'नाकामयाबी',
#  'बताना',
#  'बादल',
#  'मशहूर',
#  'देखी',
#  'दिखें',
#  'बास्टन',
#  'चहरा',
#  'आम',
#  'चढ़ेगा',
#  'लड़ूंगी',
#  'रिहा',
#  'बाहर',
#  'पेरिस',
#  'फारस',
#  'प्रक्रिया',
#  'सच्ची',
#  'बस्ता',
#  'बुलाना',
#  'दौड़ते',
#  'सुलझा',
#  'क़ानूनों',
#  'मज़े',
#  'देखें',
#  '१७५७',
#  'मार्क्स',
#  'सचाई',
#  'बचाते',
#  'कुढ़ना',
#  'आत्मविश्वासी',
#  'कचरे',
#  '७२',
#  'अंताल्या',
#  'शिवाजी',
#  'ज़िन्दा',
#  'करतें',
#  'वफादार',
#  'ज़ुबान',
#  'सदैव',
#  'विशेष',
#  'किर्गिज़िया',
#  'कुर्सियाँ',
#  'करलें',
#  'सूची',
#  'खानी',
#  'ब्राज़ीली',
#  'बाघ',
#  'गधा',
#  'दिलाते',
#  'रेखा',
#  'गुड़ियों',
#  'उनपर',
#  'जलेगा',
#  'तारीखे',
#  'नौसैनिक',
#  'कर्णाटक',
#  'दस',
#  'न्यायालय',
#  'अपनाने',
#  'तुम्हारी',
#  'करना',
#  'निर्दोश',
#  'पूछो',
#  'सीखने',
#  'सबका',
#  'बेतुका',
#  'कहे',
#  'इस्तांबुल',
#  'माफ',
#  'विज्ञान',
#  'वाली',
#  'मेल',
#  'टाइम',
#  'देखा',
#  'बातचीत',
#  'सब',
#  'डालकर',
#  'करें',
#  'वेलेंटाइन',
#  'पाते',
#  'जागतिक',
#  'बताऊंगा',
#  'मज़ाक',
#  'कैमरा',
#  'प्रावदा',
#  'रोमानिया',
#  'गद्दारी',
#  'ताईवान',
#  'मक्खन',
#  'लोगो',
#  'पेट',
#  'सच्चा',
#  'पोतियां',
#  '20',
#  'फट',
#  'हर',
#  'प्रायः',
#  'बताऊं',
#  'फ़ैसला',
#  'अजनबी',
#  'पड़ेगा',
#  'बक्से',
#  'ईमेल',
#  'चोट',
#  'शिरो',
#  'लत',
#  'लें',
#  'युवती',
#  'कॉपियाँ',
#  'क़ैदियों',
#  'ओलंपिक',
#  'कोने',
#  'टिकिट',
#  'उच्चारण',
#  'चूहे',
#  'साल्सा',
#  'असभ्य',
#  'बॉल',
#  'सीता',
#  'जन्मी',
#  'अंत',
#  'शाबाश',
#  'शिश्न',
#  'चमकेगा',
#  'भरा',
#  'ऐसा',
#  'स्टेन',
#  'सकता',
#  'दिखता',
#  'काँग',
#  'युक्रेनी',
#  'ताकि',
#  'थोड़े',
#  'क्लिक',
#  'कल',
#  'खराबी',
#  'दंत',
#  'वैनकूवर',
#  'पिघला',
#  'रखदो',
#  'जाँच',
#  'गलत',
#  'पहनना',
#  'दही',
#  'मिनट',
#  'ढूँढ',
#  'नाव',
#  'समझकर',
#  'ठहराया',
#  'घोड़े',
#  'इमाम',
#  'लॉलीपॉप',
#  'पड़ेगी',
#  'हमारी',
#  'जीतता',
#  'बॉयफ्रेंड',
#  'जलकर',
#  'वाक्यांशों',
#  'भरेगा',
#  '२',
#  'वसीयत',
#  'स्वार्थी',
#  'नन',
#  'काटकर',
#  'पतला',
#  'क्षतिपूरक',
#  'घटाने',
#  'पहचानते',
#  'शानदार',
#  ',',
#  'यॉर्क',
#  'भूलनी',
#  'रस',
#  'दूसरी',
#  'अफगानिस्तान',
#  'दिखाई',
#  'टाँगा',
#  'सिर्फ़',
#  'हड़बड़ी',
#  'पकड़ोगे',
#  'शाँत',
#  'उन',
#  'भूखें',
#  'भैंस',
#  'महाशय',
#  'तूफ़ानों',
#  'कर्ज़',
#  'सिखायी',
#  'लोमड़ियों',
#  'वोह',
#  'साक्ष्य',
#  'टोकियो',
#  'एंड्रिया',
#  'मंगवाई',
#  'म्युज़ियम',
#  'सिख',
#  'सिखाइये',
#  'ताजिकिस्तान',
#  'युएन',
#  'तोड़ी',
#  'डाँटा',
#  'बेटे',
#  'मरता',
#  'समान',
#  'मजबूर',
#  'खिंचा',
#  'निश्छल',
#  'विवाहित',
#  'मेेरी',
#  'गवाना',
#  'लूंगी',
#  'रोटी',
#  'अस्वीकार',
#  'क़ब्र',
#  'नर्सरी',
#  'आया',
#  'लड़कियों',
#  'आदतें',
#  'प्रसन्न',
#  'छोड़दी',
#  'निहत्थे',
#  'चलाई',
#  'सब्ज़ी',
#  'तहकीकात',
#  'कोर',
#  'रच',
#  'वनों',
#  'लाख',
#  'सँभाला',
#  'वाक्यांश',
#  'साहब',
#  'जीन्ज़',
#  'हम',
#  'सांस',
#  'संख्या',
#  'लिस्बन',
#  'किसको',
#  'स्विजरलैंड',
#  'दुर्प्रभावों',
#  'ब्रदर्स',
#  'आओ',
#  'सिंगापुर',
#  'बनाता',
#  'मना',
#  'ऊंचा',
#  'शो',
#  'नींद',
#  'ची',
#  'खड़ी',
#  'बीटल्स',
#  'अनार',
#  'नाओको',
#  'लगीं',
#  'ऐसे',
#  'अधनंगे',
#  'फ़्रांचेस्को',
#  'मिलाना',
#  'खीचें',
#  'फेंकने',
#  'पूछने',
#  'सोये',
#  'स्टारक्राफ़्ट',
#  'गोल',
#  'ऑफलाइन',
#  'हिफ़ाज़त',
#  'उठाइये',
#  'योनी',
#  'कमाल',
#  'आइडिया',
#  'तीस',
#  'मूर्तियाँ',
#  'सोवियेत',
#  'आह',
#  'मुसलिम',
#  'बिल',
#  'सैनिकों',
#  'औरतों',
#  'डब्बे',
#  'प्रयोगों',
#  'आंड्रे',
#  'मूल्य',
#  'माहौल',
#  'दिये',
#  'दौड़कर',
#  'ख़ज़ाना',
#  'आई',
#  'उम्मीदों',
#  'तिनके',
#  'यान्नी',
#  'रिश्तेदारों',
#  'महक',
#  'बाल्टी',
#  'वे',
#  'बताएं',
#  'खाओ',
#  'बड़ाई',
#  'विकल्पों',
#  'घूरने',
#  'सटीकता',
#  'कॉल',
#  'भगवान',
#  'सर्दी',
#  'उबलने',
#  'नन्ही',
#  '१७९९',
#  'रिति',
#  'मानचित्र',
#  'धड़ल्ले',
#  'छूटता',
#  'करवाता',
#  'मालिबू',
#  'भूलती',
#  'मौसम',
#  'स्थित',
#  'भिड़',
#  'डे',
#  'सीमित',
#  'बैठक',
#  'जवानी',
#  'चूसा',
#  'केसरी',
#  'नीन्द',
#  'अँडे',
#  'तर',
#  'रज़ाक',
#  'सैंतीस',
#  'घुलामों',
#  'लौटकर',
#  'फ़्लैट',
#  'काट',
#  'तुम',
#  'दिवाला',
#  'विध्यार्थी',
#  'नौकरानी',
#  'अफ़वा',
#  'अधिकारियों',
#  'स्थापित',
#  'किराय',
#  'रुका',
#  'अर्थतंत्रों',
#  'बाज़ी',
#  'खेलता',
#  'दल',
#  'धोई',
#  'चाकू',
#  'गति',
#  'प्रेरणा',
#  'पहुँचे',
#  'प्रदूषित',
#  '२००१',
#  'चौहत्तर',
#  'आराम',
#  'सिवाय',
#  'डूबते',
#  'व्यंजन',
#  'एशियाइयों',
#  'बूढ़े',
#  'बनेगा',
#  'घडी़',
#  'प्यार',
#  'करूँगी',
#  'नील्स',
#  'ब्रिज',
#  'गायब',
#  'पिछले',
#  'सिखाया',
#  'सुरियाह',
#  'कहिएगा',
#  'डाक',
#  'समलैंगिक',
#  'लौटाने',
#  'टिप्पणियाँ',
#  'चोदना',
#  'लोकतंत्र',
#  'चुनने',
#  'चूहा',
#  'आजीवन',
#  'बारे',
#  'गीला',
#  'मेट्रो',
#  'आक्रमण',
#  'एस्केलेटर',
#  'ठंडी',
#  'महँगा',
#  'आधा',
#  'दावा',
#  'इसको',
#  'बैठता',
#  'प्रतिक्रिया',
#  'हाशिमोतो',
#  'क्लब',
#  'लाएगा',
#  'लिपि',
#  'खत्म',
#  'समझदार',
#  'संदर्भ',
#  'टूटे',
#  'पड़ताल',
#  'विदेशी',
#  'आस्था',
#  'हिचकिचाहट',
#  'ड्रेस',
#  'चाहोगे',
#  'खाएंगे',
#  'मारा',
#  'पैगंबर',
#  'वाक्यों',
#  'हिसाशी',
#  'फ़ुकुओका',
#  'गोली',
#  'आपातकालीन',
#  'बिक',
#  'प्रस्तुत',
#  'मौके',
#  'घुमा',
#  'रक्षा',
#  'दोपहरभर',
#  'शेरों',
#  'ओई',
#  'हिन्दी',
#  'मनुष्य',
#  'पिंजरा',
#  'बहादुरी',
#  'आदी',
#  'काबिलियत',
#  'भ्रामक',
#  'बजती',
#  'गाडियों',
#  'पंद्रहवीं',
#  'माईक',
#  'लूँ',
#  'एकेश्वरवादी',
#  'राष्ट्रों',
#  'एड्स',
#  'चाहीए',
#  'अतीत',
#  'तलना',
#  'एहसान',
#  'होठ',
#  'चलकर',
#  '१९०५',
#  'द्रिश्य',
#  'बांधने',
#  'ग',
#  'सब्ज़ीयाँ',
#  'इन्तज़ार',
#  'चौबीस',
#  'कॅलगरी',
#  'हत्याएँ',
#  'आसन',
#  'ओल्ड',
#  '97',
#  'आजाओ',
#  'बगीचे',
#  'महासागर',
#  'लिंग',
#  'रुकी',
#  'चला',
#  'सफ़र',
#  'ज़ारागोज़ा',
#  'लिख',
#  'जनमत',
#  'प्रतिबद्धता',
#  'मिली',
#  'पाजामे',
#  'कैरीबियन',
#  'आधी',
#  'खट्टी',
#  'बाँधती',
#  'पटक',
#  'नानाजी',
#  'सुथरा',
#  'करो',
#  'सागरों',
#  'सूर्य',
#  'भागिए',
#  'अॅन',
#  'गर्भवती',
#  'थप्पड',
#  'टैड्डी',
#  'मश्हूर',
#  'बेचनी',
#  'टोनी',
#  'पहनूँ',
#  'मुड़ो',
#  'विस्तार',
#  'मिलें',
#  'ऊँगलीयाँ',
#  'दोबारा',
#  'गीलीं',
#  'किसानों',
#  'हिंदी',
#  'पीना',
#  'विष्व',
#  'स्वामी',
#  'चुरा',
#  'इसीलिये',
#  'सूरज',
#  '1',
#  'पहला',
#  'पोंछा',
#  'लगें',
#  'कितनीं',
#  'तोह्फ़ा',
#  'मूँछ',
#  'रेडियो',
#  'इचिरो',
#  'सितारे',
#  'फ़ोन',
#  'ख़ुशी',
#  'उल्टी',
#  'मेने',
#  'ग़ैरक़ानूनी',
#  'नवपाषाणकालीन',
#  'ही',
#  'पे',
#  'मैल',
#  'फ़िकर',
#  'सुझाव',
#  'देखो',
#  'कि',
#  'मुम्बई',
#  'खट्टे',
#  'सुगंध',
#  'बिताओगे',
#  'हार्वर्ड',
#  'स्थानीय',
#  'आँखे',
#  'आयडिया',
#  'शिखर',
#  'पेड़ों',
#  'लगेगी',
#  'दोस्तों',
#  'अनीश्वरवादी',
#  'रंग',
#  'सँकरी',
#  'छानबीन',
#  'शीत',
#  'तेजातु',
#  'शास्त्री',
#  'गुथी',
#  ...}

# %%
len(hindi_vocab)
# Out:
# 7069

# %%
Vd=dict()
for idx, token in enumerate(hindi_vocab):
    Vd[token]=idx+3
Vd["<PAD>"]=0
Vd["<SOS>"]=1
Vd["<EOS>"]=2

# %%
Vd
# Out:
# {'ग़रीब': 3,
#  'तीसरा': 4,
#  'सौन्\u200dदर्य': 5,
#  'बेची': 6,
#  'अंतरात्मा': 7,
#  'रोडिका': 8,
#  'बताता': 9,
#  'छुट्टे': 10,
#  'विवेकी': 11,
#  'जिमखाने': 12,
#  'व्यर्थ': 13,
#  'पुर्त्तगाल': 14,
#  'कोरिया': 15,
#  'बीजिंग': 16,
#  'फटाफट': 17,
#  'दूँगा': 18,
#  'फ़ेसबुक': 19,
#  'भिखारियों': 20,
#  'सदमा': 21,
#  'बेवकूफ़': 22,
#  'दिशा': 23,
#  'घर': 24,
#  'लिपटा': 25,
#  'खिलौना': 26,
#  'चेतावनी': 27,
#  'बुझता': 28,
#  'असुविधा': 29,
#  'बोतल': 30,
#  'अंधा': 31,
#  'अध्ययन': 32,
#  'बनातें': 33,
#  'निकालिए': 34,
#  'लौटूँगा': 35,
#  'स्वच्छ': 36,
#  'वेल्स': 37,
#  'बकरियों': 38,
#  'सवारी': 39,
#  'शोर': 40,
#  'खरिद': 41,
#  'सालगिरह': 42,
#  'सवार': 43,
#  'भागें': 44,
#  'बैठा': 45,
#  'उपनाम': 46,
#  'यार': 47,
#  'हटो': 48,
#  'गरम': 49,
#  'अक़सर': 50,
#  'सूट': 51,
#  'यामादा': 52,
#  'फार्म': 53,
#  'व्यक्ती': 54,
#  'पेनसिल': 55,
#  'तम्बाकू': 56,
#  'ऊँचा': 57,
#  'मलेरिया': 58,
#  'कप्तान': 59,
#  'फिसल': 60,
#  'वो': 61,
#  'सिखाए': 62,
#  'ख़त्म': 63,
#  'बदल': 64,
#  'बेचैनी': 65,
#  'सिक्कों': 66,
#  'मौज': 67,
#  'होमोसेक्सुअल': 68,
#  'दमिश्क': 69,
#  'कोशिश': 70,
#  'निरोध': 71,
#  'दंभी': 72,
#  'मानने': 73,
#  'कायदे': 74,
#  'तए': 75,
#  'या': 76,
#  'कहूं': 77,
#  'चुके': 78,
#  'स्वर्ग': 79,
#  'रेलगाड़ी': 80,
#  'फ़ायदा': 81,
#  'निराश': 82,
#  'पूछूँगा': 83,
#  'वंचित': 84,
#  'जोन': 85,
#  'जुलतीं': 86,
#  'बयान': 87,
#  'अनुवाद': 88,
#  'रंडी': 89,
#  'गाना': 90,
#  'झूठा': 91,
#  'मज़ेदार': 92,
#  'सुपर': 93,
#  'मालुम': 94,
#  'उसकी': 95,
#  'सकतें': 96,
#  'गर्दन': 97,
#  'सुशी': 98,
#  'ऐन': 99,
#  'बगुले': 100,
#  'चलाया': 101,
#  'सूझ': 102,
#  'जुलती': 103,
#  'ढूँढो': 104,
#  'घड़ी': 105,
#  'सिद्धांत': 106,
#  'पिघलेगी': 107,
#  'बतख़': 108,
#  'त्रुटियाँ': 109,
#  'खेद': 110,
#  'पत्थर': 111,
#  'चोद': 112,
#  'अकेली': 113,
#  'रोज़ी': 114,
#  'सुन': 115,
#  'ड्रुक': 116,
#  'स्काटिश': 117,
#  'डरा': 118,
#  'धुलवानीं': 119,
#  'अपमानजनक': 120,
#  'मत': 121,
#  'ईसप': 122,
#  'थप्पड़': 123,
#  'टांगें': 124,
#  'मंज़िल': 125,
#  'पहुँचाई': 126,
#  'तज़ुर्बे': 127,
#  'पट्टी': 128,
#  'स्कीर': 129,
#  'चाहतीं': 130,
#  'नाज़ी': 131,
#  'जानते': 132,
#  'शिकागो': 133,
#  'दीमक': 134,
#  'सीरिया': 135,
#  'भूमध्य': 136,
#  'क्रीम': 137,
#  'कोशीश': 138,
#  'बताउँगी': 139,
#  'लिए': 140,
#  'दवाइयां': 141,
#  'छीन': 142,
#  'स्तुति': 143,
#  'बिस्तर': 144,
#  'वृषभ': 145,
#  'नाभिकीय': 146,
#  'अफ़वाह': 147,
#  'समझती': 148,
#  'खत': 149,
#  'पकाया': 150,
#  'ख़ूब': 151,
#  'फॉन्ट': 152,
#  'नताशा': 153,
#  'आए': 154,
#  'प्रदर्शन': 155,
#  'चूमने': 156,
#  'अपनाएं': 157,
#  'जाऊं': 158,
#  '१६३६': 159,
#  'डाक्टर': 160,
#  'इनका': 161,
#  'इतिहासकार': 162,
#  'मूठ': 163,
#  'नैनसी': 164,
#  'बह': 165,
#  'जानबूझकर': 166,
#  'पूंछ': 167,
#  'डचेस': 168,
#  'पसंदीदा': 169,
#  'आपका': 170,
#  'डरते': 171,
#  'बहरीन': 172,
#  'बोल': 173,
#  'एओस्तेराइख़': 174,
#  'किन्तु': 175,
#  'बहनें': 176,
#  'चाहेंगी': 177,
#  'दरवाजे': 178,
#  'आँखें': 179,
#  'घिसे': 180,
#  'ओपनर': 181,
#  'हिलो': 182,
#  'फ़सल': 183,
#  'घुसा': 184,
#  'पैरीस': 185,
#  'रोज़ाना': 186,
#  'रोज़': 187,
#  'साफ़': 188,
#  'बेल्जियाई': 189,
#  'प्रसिद्ध': 190,
#  'गी': 191,
#  'इलाक़ा': 192,
#  'निकलने': 193,
#  'समझाई': 194,
#  'सवाल': 195,
#  'धमाके': 196,
#  'सावन': 197,
#  'परिस्तिथि': 198,
#  'निपुण': 199,
#  'रक्त': 200,
#  'एस': 201,
#  'महिलाओं': 202,
#  'दिवालिया': 203,
#  'नज़्म': 204,
#  'दिवाई': 205,
#  'व्याप्त': 206,
#  'कबाड़': 207,
#  'सिक्का': 208,
#  'प्रदूषण': 209,
#  'हस्तमैथुन': 210,
#  'शराबख़ाना': 211,
#  'कमर': 212,
#  'पतलून': 213,
#  'सपने': 214,
#  'कक्ष': 215,
#  'सफ़ल': 216,
#  'गुजरात': 217,
#  'हस्पताल': 218,
#  'समिति': 219,
#  'भरे': 220,
#  'लुसी': 221,
#  'भौंकने': 222,
#  'टिकती': 223,
#  'हाँग': 224,
#  'थम': 225,
#  'मोटे': 226,
#  'पराकाष्ठा': 227,
#  'तीर': 228,
#  'पीया': 229,
#  'आयेगा': 230,
#  'लौटें': 231,
#  'घूमफिरकर': 232,
#  'वदीयत': 233,
#  'अन्तरात्मा': 234,
#  'समझाया': 235,
#  'लाती': 236,
#  'कोमा': 237,
#  'डिक्की': 238,
#  'इन्टरनेट': 239,
#  'रिमोट': 240,
#  'दूँगी': 241,
#  'द': 242,
#  '२०१३': 243,
#  'चाकलेट': 244,
#  '१९७९': 245,
#  'ज़िद्दी': 246,
#  'धूल': 247,
#  'करुँगी': 248,
#  'डिंग': 249,
#  'वाले': 250,
#  'सर्व': 251,
#  'से': 252,
#  'हालांकि': 253,
#  'अनुभूति': 254,
#  'नेटफ़्लिक्स': 255,
#  'भेजा': 256,
#  'चलोगे': 257,
#  'धत्': 258,
#  'क़ैदी': 259,
#  'आतंक': 260,
#  'तापमान': 261,
#  'खतरा': 262,
#  'भुला': 263,
#  'संक्षिप्त': 264,
#  'सकें': 265,
#  'पाकिस्तान': 266,
#  'फ़्रांस': 267,
#  'केवल': 268,
#  'उस': 269,
#  'पंथ': 270,
#  'पड़ोस': 271,
#  'किताबें': 272,
#  'सोवियत': 273,
#  'गलतियां': 274,
#  'मिस्र': 275,
#  'ओबोन': 276,
#  'थोडी': 277,
#  'बहुमत': 278,
#  'मेन्नाद': 279,
#  'बर्फ': 280,
#  'जानो': 281,
#  'आके': 282,
#  'संरक्षण': 283,
#  'नारिता': 284,
#  'सोकर': 285,
#  'आखरी': 286,
#  'कबार': 287,
#  'भेजने': 288,
#  'कीव': 289,
#  'उत्तेजित': 290,
#  'बिज्जू': 291,
#  'बनाओगे': 292,
#  'हुमायून': 293,
#  'टैबलेट': 294,
#  'माफी': 295,
#  'बढ़ी': 296,
#  '?': 297,
#  'खट्टा': 298,
#  'गोलीबारी': 299,
#  'सक्रिय': 300,
#  'फैलाये': 301,
#  'केल्टिक': 302,
#  'करुंगा': 303,
#  'स्कैनर': 304,
#  'व्यक्त': 305,
#  'थोडे': 306,
#  'ईनाम': 307,
#  'सेवाओं': 308,
#  'टॅाम': 309,
#  'धीरे': 310,
#  'बाढ़': 311,
#  'क़ुतुब': 312,
#  'ड्यूटी': 313,
#  'भरोसेमंद': 314,
#  'फ़िदा': 315,
#  'कंजूस': 316,
#  'क्रूर': 317,
#  'फ़िल्में': 318,
#  'दीवालिया': 319,
#  'जीभ': 320,
#  'लूसिया': 321,
#  'बड़ी': 322,
#  'अखबारों': 323,
#  'आयात': 324,
#  'मित्र': 325,
#  'बुझाया': 326,
#  'छाता': 327,
#  'हिस्से': 328,
#  'भूलना': 329,
#  'बजाई': 330,
#  'लेलिया': 331,
#  'अक्साई': 332,
#  'परख': 333,
#  'कल्पना': 334,
#  'खोल': 335,
#  'गुम': 336,
#  'क़ीमत': 337,
#  'लौटते': 338,
#  'इनके': 339,
#  'दिल': 340,
#  'अरबी': 341,
#  'शिशु': 342,
#  'जीते': 343,
#  'भागते': 344,
#  'ला': 345,
#  'नाइट': 346,
#  'उपलब्ध': 347,
#  'ज़बान': 348,
#  'भूत': 349,
#  'धीमी': 350,
#  'करनीं': 351,
#  'परिवार': 352,
#  'निकाला': 353,
#  'स्टेट': 354,
#  'वैश्विक': 355,
#  'लानत': 356,
#  'कोकोनट': 357,
#  'डैन': 358,
#  'छोड़ो': 359,
#  'डोमिनिकाना': 360,
#  'विस्फोटो': 361,
#  'गौल्फ़': 362,
#  'बड़ा': 363,
#  'जापान': 364,
#  'राजधानीयां': 365,
#  'उसको': 366,
#  'सिगार': 367,
#  'अक्टूबर': 368,
#  'पंख': 369,
#  'जानवर': 370,
#  'छपेगी': 371,
#  'फिराया': 372,
#  'हटा': 373,
#  '११९': 374,
#  'ज़िरी': 375,
#  'पुर्तगाल': 376,
#  'लिंकन': 377,
#  'देखतीं': 378,
#  'ऑफिसर': 379,
#  'बरी': 380,
#  'कही': 381,
#  'समझाएं': 382,
#  'बेआराम': 383,
#  'प्रोसेसर': 384,
#  'हास्यस्पद': 385,
#  'यरुशलम': 386,
#  'बाइकाल': 387,
#  'होगे': 388,
#  '१९५७': 389,
#  'मूर्ख': 390,
#  'सम्पर्क': 391,
#  '३०': 392,
#  'सेहत': 393,
#  'तरक़ीब': 394,
#  'दूत': 395,
#  'शिक्षा': 396,
#  'सोचना': 397,
#  'स्पोर्ट्स': 398,
#  'दुष्ट': 399,
#  'चाहें': 400,
#  'अक्सर': 401,
#  'बुआ': 402,
#  'इमारतें': 403,
#  'निभाना': 404,
#  'गुड': 405,
#  'चतुर': 406,
#  'यूनानी': 407,
#  'भाईचारे': 408,
#  'टुकड़ों': 409,
#  'तिरंगा': 410,
#  'चलती': 411,
#  'बिल्ले': 412,
#  'गयें': 413,
#  '१९९०': 414,
#  'भरना': 415,
#  'सीखते': 416,
#  'पिलाओ': 417,
#  'ये': 418,
#  'तौलिए': 419,
#  'सुँघाई': 420,
#  'छोटे': 421,
#  'निकला': 422,
#  'जलने': 423,
#  'जेठ': 424,
#  'खतम': 425,
#  'प्रातःकाल': 426,
#  'चीनी': 427,
#  'पार्सल': 428,
#  'लाईं': 429,
#  'विघटित': 430,
#  'रेल': 431,
#  'अंडा': 432,
#  'चीज़ों': 433,
#  'कामकाज': 434,
#  'ऑनलाइन': 435,
#  'रोक': 436,
#  'प्रस्थापित': 437,
#  'खुशखबरी': 438,
#  'लाऊँगी': 439,
#  'मचाओ': 440,
#  'वैध': 441,
#  'ख़त': 442,
#  'सयाने': 443,
#  'भागे': 444,
#  'जुट': 445,
#  'झगड़ा': 446,
#  'बार्सेलोना': 447,
#  'प्रात': 448,
#  'टॉब': 449,
#  'ज़िन्दगी': 450,
#  'उसे': 451,
#  'दिली': 452,
#  'गलियारा': 453,
#  'मामा': 454,
#  'करीं': 455,
#  'जॉगिंग': 456,
#  'वस्\u200dतु': 457,
#  'कुछ': 458,
#  'चमक': 459,
#  'दीजिएगा': 460,
#  'औरडर': 461,
#  'नाकामयाबी': 462,
#  'बताना': 463,
#  'बादल': 464,
#  'मशहूर': 465,
#  'देखी': 466,
#  'दिखें': 467,
#  'बास्टन': 468,
#  'चहरा': 469,
#  'आम': 470,
#  'चढ़ेगा': 471,
#  'लड़ूंगी': 472,
#  'रिहा': 473,
#  'बाहर': 474,
#  'पेरिस': 475,
#  'फारस': 476,
#  'प्रक्रिया': 477,
#  'सच्ची': 478,
#  'बस्ता': 479,
#  'बुलाना': 480,
#  'दौड़ते': 481,
#  'सुलझा': 482,
#  'क़ानूनों': 483,
#  'मज़े': 484,
#  'देखें': 485,
#  '१७५७': 486,
#  'मार्क्स': 487,
#  'सचाई': 488,
#  'बचाते': 489,
#  'कुढ़ना': 490,
#  'आत्मविश्वासी': 491,
#  'कचरे': 492,
#  '७२': 493,
#  'अंताल्या': 494,
#  'शिवाजी': 495,
#  'ज़िन्दा': 496,
#  'करतें': 497,
#  'वफादार': 498,
#  'ज़ुबान': 499,
#  'सदैव': 500,
#  'विशेष': 501,
#  'किर्गिज़िया': 502,
#  'कुर्सियाँ': 503,
#  'करलें': 504,
#  'सूची': 505,
#  'खानी': 506,
#  'ब्राज़ीली': 507,
#  'बाघ': 508,
#  'गधा': 509,
#  'दिलाते': 510,
#  'रेखा': 511,
#  'गुड़ियों': 512,
#  'उनपर': 513,
#  'जलेगा': 514,
#  'तारीखे': 515,
#  'नौसैनिक': 516,
#  'कर्णाटक': 517,
#  'दस': 518,
#  'न्यायालय': 519,
#  'अपनाने': 520,
#  'तुम्हारी': 521,
#  'करना': 522,
#  'निर्दोश': 523,
#  'पूछो': 524,
#  'सीखने': 525,
#  'सबका': 526,
#  'बेतुका': 527,
#  'कहे': 528,
#  'इस्तांबुल': 529,
#  'माफ': 530,
#  'विज्ञान': 531,
#  'वाली': 532,
#  'मेल': 533,
#  'टाइम': 534,
#  'देखा': 535,
#  'बातचीत': 536,
#  'सब': 537,
#  'डालकर': 538,
#  'करें': 539,
#  'वेलेंटाइन': 540,
#  'पाते': 541,
#  'जागतिक': 542,
#  'बताऊंगा': 543,
#  'मज़ाक': 544,
#  'कैमरा': 545,
#  'प्रावदा': 546,
#  'रोमानिया': 547,
#  'गद्दारी': 548,
#  'ताईवान': 549,
#  'मक्खन': 550,
#  'लोगो': 551,
#  'पेट': 552,
#  'सच्चा': 553,
#  'पोतियां': 554,
#  '20': 555,
#  'फट': 556,
#  'हर': 557,
#  'प्रायः': 558,
#  'बताऊं': 559,
#  'फ़ैसला': 560,
#  'अजनबी': 561,
#  'पड़ेगा': 562,
#  'बक्से': 563,
#  'ईमेल': 564,
#  'चोट': 565,
#  'शिरो': 566,
#  'लत': 567,
#  'लें': 568,
#  'युवती': 569,
#  'कॉपियाँ': 570,
#  'क़ैदियों': 571,
#  'ओलंपिक': 572,
#  'कोने': 573,
#  'टिकिट': 574,
#  'उच्चारण': 575,
#  'चूहे': 576,
#  'साल्सा': 577,
#  'असभ्य': 578,
#  'बॉल': 579,
#  'सीता': 580,
#  'जन्मी': 581,
#  'अंत': 582,
#  'शाबाश': 583,
#  'शिश्न': 584,
#  'चमकेगा': 585,
#  'भरा': 586,
#  'ऐसा': 587,
#  'स्टेन': 588,
#  'सकता': 589,
#  'दिखता': 590,
#  'काँग': 591,
#  'युक्रेनी': 592,
#  'ताकि': 593,
#  'थोड़े': 594,
#  'क्लिक': 595,
#  'कल': 596,
#  'खराबी': 597,
#  'दंत': 598,
#  'वैनकूवर': 599,
#  'पिघला': 600,
#  'रखदो': 601,
#  'जाँच': 602,
#  'गलत': 603,
#  'पहनना': 604,
#  'दही': 605,
#  'मिनट': 606,
#  'ढूँढ': 607,
#  'नाव': 608,
#  'समझकर': 609,
#  'ठहराया': 610,
#  'घोड़े': 611,
#  'इमाम': 612,
#  'लॉलीपॉप': 613,
#  'पड़ेगी': 614,
#  'हमारी': 615,
#  'जीतता': 616,
#  'बॉयफ्रेंड': 617,
#  'जलकर': 618,
#  'वाक्यांशों': 619,
#  'भरेगा': 620,
#  '२': 621,
#  'वसीयत': 622,
#  'स्वार्थी': 623,
#  'नन': 624,
#  'काटकर': 625,
#  'पतला': 626,
#  'क्षतिपूरक': 627,
#  'घटाने': 628,
#  'पहचानते': 629,
#  'शानदार': 630,
#  ',': 631,
#  'यॉर्क': 632,
#  'भूलनी': 633,
#  'रस': 634,
#  'दूसरी': 635,
#  'अफगानिस्तान': 636,
#  'दिखाई': 637,
#  'टाँगा': 638,
#  'सिर्फ़': 639,
#  'हड़बड़ी': 640,
#  'पकड़ोगे': 641,
#  'शाँत': 642,
#  'उन': 643,
#  'भूखें': 644,
#  'भैंस': 645,
#  'महाशय': 646,
#  'तूफ़ानों': 647,
#  'कर्ज़': 648,
#  'सिखायी': 649,
#  'लोमड़ियों': 650,
#  'वोह': 651,
#  'साक्ष्य': 652,
#  'टोकियो': 653,
#  'एंड्रिया': 654,
#  'मंगवाई': 655,
#  'म्युज़ियम': 656,
#  'सिख': 657,
#  'सिखाइये': 658,
#  'ताजिकिस्तान': 659,
#  'युएन': 660,
#  'तोड़ी': 661,
#  'डाँटा': 662,
#  'बेटे': 663,
#  'मरता': 664,
#  'समान': 665,
#  'मजबूर': 666,
#  'खिंचा': 667,
#  'निश्छल': 668,
#  'विवाहित': 669,
#  'मेेरी': 670,
#  'गवाना': 671,
#  'लूंगी': 672,
#  'रोटी': 673,
#  'अस्वीकार': 674,
#  'क़ब्र': 675,
#  'नर्सरी': 676,
#  'आया': 677,
#  'लड़कियों': 678,
#  'आदतें': 679,
#  'प्रसन्न': 680,
#  'छोड़दी': 681,
#  'निहत्थे': 682,
#  'चलाई': 683,
#  'सब्ज़ी': 684,
#  'तहकीकात': 685,
#  'कोर': 686,
#  'रच': 687,
#  'वनों': 688,
#  'लाख': 689,
#  'सँभाला': 690,
#  'वाक्यांश': 691,
#  'साहब': 692,
#  'जीन्ज़': 693,
#  'हम': 694,
#  'सांस': 695,
#  'संख्या': 696,
#  'लिस्बन': 697,
#  'किसको': 698,
#  'स्विजरलैंड': 699,
#  'दुर्प्रभावों': 700,
#  'ब्रदर्स': 701,
#  'आओ': 702,
#  'सिंगापुर': 703,
#  'बनाता': 704,
#  'मना': 705,
#  'ऊंचा': 706,
#  'शो': 707,
#  'नींद': 708,
#  'ची': 709,
#  'खड़ी': 710,
#  'बीटल्स': 711,
#  'अनार': 712,
#  'नाओको': 713,
#  'लगीं': 714,
#  'ऐसे': 715,
#  'अधनंगे': 716,
#  'फ़्रांचेस्को': 717,
#  'मिलाना': 718,
#  'खीचें': 719,
#  'फेंकने': 720,
#  'पूछने': 721,
#  'सोये': 722,
#  'स्टारक्राफ़्ट': 723,
#  'गोल': 724,
#  'ऑफलाइन': 725,
#  'हिफ़ाज़त': 726,
#  'उठाइये': 727,
#  'योनी': 728,
#  'कमाल': 729,
#  'आइडिया': 730,
#  'तीस': 731,
#  'मूर्तियाँ': 732,
#  'सोवियेत': 733,
#  'आह': 734,
#  'मुसलिम': 735,
#  'बिल': 736,
#  'सैनिकों': 737,
#  'औरतों': 738,
#  'डब्बे': 739,
#  'प्रयोगों': 740,
#  'आंड्रे': 741,
#  'मूल्य': 742,
#  'माहौल': 743,
#  'दिये': 744,
#  'दौड़कर': 745,
#  'ख़ज़ाना': 746,
#  'आई': 747,
#  'उम्मीदों': 748,
#  'तिनके': 749,
#  'यान्नी': 750,
#  'रिश्तेदारों': 751,
#  'महक': 752,
#  'बाल्टी': 753,
#  'वे': 754,
#  'बताएं': 755,
#  'खाओ': 756,
#  'बड़ाई': 757,
#  'विकल्पों': 758,
#  'घूरने': 759,
#  'सटीकता': 760,
#  'कॉल': 761,
#  'भगवान': 762,
#  'सर्दी': 763,
#  'उबलने': 764,
#  'नन्ही': 765,
#  '१७९९': 766,
#  'रिति': 767,
#  'मानचित्र': 768,
#  'धड़ल्ले': 769,
#  'छूटता': 770,
#  'करवाता': 771,
#  'मालिबू': 772,
#  'भूलती': 773,
#  'मौसम': 774,
#  'स्थित': 775,
#  'भिड़': 776,
#  'डे': 777,
#  'सीमित': 778,
#  'बैठक': 779,
#  'जवानी': 780,
#  'चूसा': 781,
#  'केसरी': 782,
#  'नीन्द': 783,
#  'अँडे': 784,
#  'तर': 785,
#  'रज़ाक': 786,
#  'सैंतीस': 787,
#  'घुलामों': 788,
#  'लौटकर': 789,
#  'फ़्लैट': 790,
#  'काट': 791,
#  'तुम': 792,
#  'दिवाला': 793,
#  'विध्यार्थी': 794,
#  'नौकरानी': 795,
#  'अफ़वा': 796,
#  'अधिकारियों': 797,
#  'स्थापित': 798,
#  'किराय': 799,
#  'रुका': 800,
#  'अर्थतंत्रों': 801,
#  'बाज़ी': 802,
#  'खेलता': 803,
#  'दल': 804,
#  'धोई': 805,
#  'चाकू': 806,
#  'गति': 807,
#  'प्रेरणा': 808,
#  'पहुँचे': 809,
#  'प्रदूषित': 810,
#  '२००१': 811,
#  'चौहत्तर': 812,
#  'आराम': 813,
#  'सिवाय': 814,
#  'डूबते': 815,
#  'व्यंजन': 816,
#  'एशियाइयों': 817,
#  'बूढ़े': 818,
#  'बनेगा': 819,
#  'घडी़': 820,
#  'प्यार': 821,
#  'करूँगी': 822,
#  'नील्स': 823,
#  'ब्रिज': 824,
#  'गायब': 825,
#  'पिछले': 826,
#  'सिखाया': 827,
#  'सुरियाह': 828,
#  'कहिएगा': 829,
#  'डाक': 830,
#  'समलैंगिक': 831,
#  'लौटाने': 832,
#  'टिप्पणियाँ': 833,
#  'चोदना': 834,
#  'लोकतंत्र': 835,
#  'चुनने': 836,
#  'चूहा': 837,
#  'आजीवन': 838,
#  'बारे': 839,
#  'गीला': 840,
#  'मेट्रो': 841,
#  'आक्रमण': 842,
#  'एस्केलेटर': 843,
#  'ठंडी': 844,
#  'महँगा': 845,
#  'आधा': 846,
#  'दावा': 847,
#  'इसको': 848,
#  'बैठता': 849,
#  'प्रतिक्रिया': 850,
#  'हाशिमोतो': 851,
#  'क्लब': 852,
#  'लाएगा': 853,
#  'लिपि': 854,
#  'खत्म': 855,
#  'समझदार': 856,
#  'संदर्भ': 857,
#  'टूटे': 858,
#  'पड़ताल': 859,
#  'विदेशी': 860,
#  'आस्था': 861,
#  'हिचकिचाहट': 862,
#  'ड्रेस': 863,
#  'चाहोगे': 864,
#  'खाएंगे': 865,
#  'मारा': 866,
#  'पैगंबर': 867,
#  'वाक्यों': 868,
#  'हिसाशी': 869,
#  'फ़ुकुओका': 870,
#  'गोली': 871,
#  'आपातकालीन': 872,
#  'बिक': 873,
#  'प्रस्तुत': 874,
#  'मौके': 875,
#  'घुमा': 876,
#  'रक्षा': 877,
#  'दोपहरभर': 878,
#  'शेरों': 879,
#  'ओई': 880,
#  'हिन्दी': 881,
#  'मनुष्य': 882,
#  'पिंजरा': 883,
#  'बहादुरी': 884,
#  'आदी': 885,
#  'काबिलियत': 886,
#  'भ्रामक': 887,
#  'बजती': 888,
#  'गाडियों': 889,
#  'पंद्रहवीं': 890,
#  'माईक': 891,
#  'लूँ': 892,
#  'एकेश्वरवादी': 893,
#  'राष्ट्रों': 894,
#  'एड्स': 895,
#  'चाहीए': 896,
#  'अतीत': 897,
#  'तलना': 898,
#  'एहसान': 899,
#  'होठ': 900,
#  'चलकर': 901,
#  '१९०५': 902,
#  'द्रिश्य': 903,
#  'बांधने': 904,
#  'ग': 905,
#  'सब्ज़ीयाँ': 906,
#  'इन्तज़ार': 907,
#  'चौबीस': 908,
#  'कॅलगरी': 909,
#  'हत्याएँ': 910,
#  'आसन': 911,
#  'ओल्ड': 912,
#  '97': 913,
#  'आजाओ': 914,
#  'बगीचे': 915,
#  'महासागर': 916,
#  'लिंग': 917,
#  'रुकी': 918,
#  'चला': 919,
#  'सफ़र': 920,
#  'ज़ारागोज़ा': 921,
#  'लिख': 922,
#  'जनमत': 923,
#  'प्रतिबद्धता': 924,
#  'मिली': 925,
#  'पाजामे': 926,
#  'कैरीबियन': 927,
#  'आधी': 928,
#  'खट्टी': 929,
#  'बाँधती': 930,
#  'पटक': 931,
#  'नानाजी': 932,
#  'सुथरा': 933,
#  'करो': 934,
#  'सागरों': 935,
#  'सूर्य': 936,
#  'भागिए': 937,
#  'अॅन': 938,
#  'गर्भवती': 939,
#  'थप्पड': 940,
#  'टैड्डी': 941,
#  'मश्हूर': 942,
#  'बेचनी': 943,
#  'टोनी': 944,
#  'पहनूँ': 945,
#  'मुड़ो': 946,
#  'विस्तार': 947,
#  'मिलें': 948,
#  'ऊँगलीयाँ': 949,
#  'दोबारा': 950,
#  'गीलीं': 951,
#  'किसानों': 952,
#  'हिंदी': 953,
#  'पीना': 954,
#  'विष्व': 955,
#  'स्वामी': 956,
#  'चुरा': 957,
#  'इसीलिये': 958,
#  'सूरज': 959,
#  '1': 960,
#  'पहला': 961,
#  'पोंछा': 962,
#  'लगें': 963,
#  'कितनीं': 964,
#  'तोह्फ़ा': 965,
#  'मूँछ': 966,
#  'रेडियो': 967,
#  'इचिरो': 968,
#  'सितारे': 969,
#  'फ़ोन': 970,
#  'ख़ुशी': 971,
#  'उल्टी': 972,
#  'मेने': 973,
#  'ग़ैरक़ानूनी': 974,
#  'नवपाषाणकालीन': 975,
#  'ही': 976,
#  'पे': 977,
#  'मैल': 978,
#  'फ़िकर': 979,
#  'सुझाव': 980,
#  'देखो': 981,
#  'कि': 982,
#  'मुम्बई': 983,
#  'खट्टे': 984,
#  'सुगंध': 985,
#  'बिताओगे': 986,
#  'हार्वर्ड': 987,
#  'स्थानीय': 988,
#  'आँखे': 989,
#  'आयडिया': 990,
#  'शिखर': 991,
#  'पेड़ों': 992,
#  'लगेगी': 993,
#  'दोस्तों': 994,
#  'अनीश्वरवादी': 995,
#  'रंग': 996,
#  'सँकरी': 997,
#  'छानबीन': 998,
#  'शीत': 999,
#  'तेजातु': 1000,
#  'शास्त्री': 1001,
#  'गुथी': 1002,
#  ...}

# %%
print(Vd)
# Out:
# {'ग़रीब': 3, 'तीसरा': 4, 'सौन्\u200dदर्य': 5, 'बेची': 6, 'अंतरात्मा': 7, 'रोडिका': 8, 'बताता': 9, 'छुट्टे': 10, 'विवेकी': 11, 'जिमखाने': 12, 'व्यर्थ': 13, 'पुर्त्तगाल': 14, 'कोरिया': 15, 'बीजिंग': 16, 'फटाफट': 17, 'दूँगा': 18, 'फ़ेसबुक': 19, 'भिखारियों': 20, 'सदमा': 21, 'बेवकूफ़': 22, 'दिशा': 23, 'घर': 24, 'लिपटा': 25, 'खिलौना': 26, 'चेतावनी': 27, 'बुझता': 28, 'असुविधा': 29, 'बोतल': 30, 'अंधा': 31, 'अध्ययन': 32, 'बनातें': 33, 'निकालिए': 34, 'लौटूँगा': 35, 'स्वच्छ': 36, 'वेल्स': 37, 'बकरियों': 38, 'सवारी': 39, 'शोर': 40, 'खरिद': 41, 'सालगिरह': 42, 'सवार': 43, 'भागें': 44, 'बैठा': 45, 'उपनाम': 46, 'यार': 47, 'हटो': 48, 'गरम': 49, 'अक़सर': 50, 'सूट': 51, 'यामादा': 52, 'फार्म': 53, 'व्यक्ती': 54, 'पेनसिल': 55, 'तम्बाकू': 56, 'ऊँचा': 57, 'मलेरिया': 58, 'कप्तान': 59, 'फिसल': 60, 'वो': 61, 'सिखाए': 62, 'ख़त्म': 63, 'बदल': 64, 'बेचैनी': 65, 'सिक्कों': 66, 'मौज': 67, 'होमोसेक्सुअल': 68, 'दमिश्क': 69, 'कोशिश': 70, 'निरोध': 71, 'दंभी': 72, 'मानने': 73, 'कायदे': 74, 'तए': 75, 'या': 76, 'कहूं': 77, 'चुके': 78, 'स्वर्ग': 79, 'रेलगाड़ी': 80, 'फ़ायदा': 81, 'निराश': 82, 'पूछूँगा': 83, 'वंचित': 84, 'जोन': 85, 'जुलतीं': 86, 'बयान': 87, 'अनुवाद': 88, 'रंडी': 89, 'गाना': 90, 'झूठा': 91, 'मज़ेदार': 92, 'सुपर': 93, 'मालुम': 94, 'उसकी': 95, 'सकतें': 96, 'गर्दन': 97, 'सुशी': 98, 'ऐन': 99, 'बगुले': 100, 'चलाया': 101, 'सूझ': 102, 'जुलती': 103, 'ढूँढो': 104, 'घड़ी': 105, 'सिद्धांत': 106, 'पिघलेगी': 107, 'बतख़': 108, 'त्रुटियाँ': 109, 'खेद': 110, 'पत्थर': 111, 'चोद': 112, 'अकेली': 113, 'रोज़ी': 114, 'सुन': 115, 'ड्रुक': 116, 'स्काटिश': 117, 'डरा': 118, 'धुलवानीं': 119, 'अपमानजनक': 120, 'मत': 121, 'ईसप': 122, 'थप्पड़': 123, 'टांगें': 124, 'मंज़िल': 125, 'पहुँचाई': 126, 'तज़ुर्बे': 127, 'पट्टी': 128, 'स्कीर': 129, 'चाहतीं': 130, 'नाज़ी': 131, 'जानते': 132, 'शिकागो': 133, 'दीमक': 134, 'सीरिया': 135, 'भूमध्य': 136, 'क्रीम': 137, 'कोशीश': 138, 'बताउँगी': 139, 'लिए': 140, 'दवाइयां': 141, 'छीन': 142, 'स्तुति': 143, 'बिस्तर': 144, 'वृषभ': 145, 'नाभिकीय': 146, 'अफ़वाह': 147, 'समझती': 148, 'खत': 149, 'पकाया': 150, 'ख़ूब': 151, 'फॉन्ट': 152, 'नताशा': 153, 'आए': 154, 'प्रदर्शन': 155, 'चूमने': 156, 'अपनाएं': 157, 'जाऊं': 158, '१६३६': 159, 'डाक्टर': 160, 'इनका': 161, 'इतिहासकार': 162, 'मूठ': 163, 'नैनसी': 164, 'बह': 165, 'जानबूझकर': 166, 'पूंछ': 167, 'डचेस': 168, 'पसंदीदा': 169, 'आपका': 170, 'डरते': 171, 'बहरीन': 172, 'बोल': 173, 'एओस्तेराइख़': 174, 'किन्तु': 175, 'बहनें': 176, 'चाहेंगी': 177, 'दरवाजे': 178, 'आँखें': 179, 'घिसे': 180, 'ओपनर': 181, 'हिलो': 182, 'फ़सल': 183, 'घुसा': 184, 'पैरीस': 185, 'रोज़ाना': 186, 'रोज़': 187, 'साफ़': 188, 'बेल्जियाई': 189, 'प्रसिद्ध': 190, 'गी': 191, 'इलाक़ा': 192, 'निकलने': 193, 'समझाई': 194, 'सवाल': 195, 'धमाके': 196, 'सावन': 197, 'परिस्तिथि': 198, 'निपुण': 199, 'रक्त': 200, 'एस': 201, 'महिलाओं': 202, 'दिवालिया': 203, 'नज़्म': 204, 'दिवाई': 205, 'व्याप्त': 206, 'कबाड़': 207, 'सिक्का': 208, 'प्रदूषण': 209, 'हस्तमैथुन': 210, 'शराबख़ाना': 211, 'कमर': 212, 'पतलून': 213, 'सपने': 214, 'कक्ष': 215, 'सफ़ल': 216, 'गुजरात': 217, 'हस्पताल': 218, 'समिति': 219, 'भरे': 220, 'लुसी': 221, 'भौंकने': 222, 'टिकती': 223, 'हाँग': 224, 'थम': 225, 'मोटे': 226, 'पराकाष्ठा': 227, 'तीर': 228, 'पीया': 229, 'आयेगा': 230, 'लौटें': 231, 'घूमफिरकर': 232, 'वदीयत': 233, 'अन्तरात्मा': 234, 'समझाया': 235, 'लाती': 236, 'कोमा': 237, 'डिक्की': 238, 'इन्टरनेट': 239, 'रिमोट': 240, 'दूँगी': 241, 'द': 242, '२०१३': 243, 'चाकलेट': 244, '१९७९': 245, 'ज़िद्दी': 246, 'धूल': 247, 'करुँगी': 248, 'डिंग': 249, 'वाले': 250, 'सर्व': 251, 'से': 252, 'हालांकि': 253, 'अनुभूति': 254, 'नेटफ़्लिक्स': 255, 'भेजा': 256, 'चलोगे': 257, 'धत्': 258, 'क़ैदी': 259, 'आतंक': 260, 'तापमान': 261, 'खतरा': 262, 'भुला': 263, 'संक्षिप्त': 264, 'सकें': 265, 'पाकिस्तान': 266, 'फ़्रांस': 267, 'केवल': 268, 'उस': 269, 'पंथ': 270, 'पड़ोस': 271, 'किताबें': 272, 'सोवियत': 273, 'गलतियां': 274, 'मिस्र': 275, 'ओबोन': 276, 'थोडी': 277, 'बहुमत': 278, 'मेन्नाद': 279, 'बर्फ': 280, 'जानो': 281, 'आके': 282, 'संरक्षण': 283, 'नारिता': 284, 'सोकर': 285, 'आखरी': 286, 'कबार': 287, 'भेजने': 288, 'कीव': 289, 'उत्तेजित': 290, 'बि ...

# %%
len(Vd)
# Out:
# 7072

# %%
def convert_hindi_tokens_to_ids(hindi_sent):
    return [Vd[token]for token in hindi_sent]

# %%
data["DstSent"]=data["DstSent"].apply(lambda x:convert_hindi_tokens_to_ids(x))

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent
# 0  [1125, 6765, 5109, 4861, 2264, 1753, 7005, 199...
# 1         [1125, 6765, 5109, 4861, 2264, 1996, 6368]
# 2  [1642, 4450, 2611, 4294, 396, 3598, 5405, 82, ...
# 3                           [5505, 4616, 3440, 6368]
# 4          [1067, 521, 5186, 5525, 2495, 1996, 6368]

# %%
def insert_sos_token_id(hindi_sent_token_ids):
    return [1] + hindi_sent_token_ids

# %%
data["DstSentInput"]=data["DstSent"].apply(lambda x: insert_sos_token_id(x))

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent  \
# 0  [1125, 6765, 5109, 4861, 2264, 1753, 7005, 199...
# 1         [1125, 6765, 5109, 4861, 2264, 1996, 6368]
# 2  [1642, 4450, 2611, 4294, 396, 3598, 5405, 82, ...
# 3                           [5505, 4616, 3440, 6368]
# 4          [1067, 521, 5186, 5525, 2495, 1996, 6368]
#
#                                         DstSentInput
# 0  [1, 1125, 6765, 5109, 4861, 2264, 1753, 7005, ...
# 1      [1, 1125, 6765, 5109, 4861, 2264, 1996, 6368]
# 2  [1, 1642, 4450, 2611, 4294, 396, 3598, 5405, 8...
# 3                        [1, 5505, 4616, 3440, 6368]
# 4       [1, 1067, 521, 5186, 5525, 2495, 1996, 6368]

# %%
def insert_eos_token_id(hindi_sent_token_ids):
    return hindi_sent_token_ids +[2]

# %%
data["DstSentLabel"]=data["DstSent"].apply(lambda x: insert_eos_token_id(x))

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent  \
# 0  [1125, 6765, 5109, 4861, 2264, 1753, 7005, 199...
# 1         [1125, 6765, 5109, 4861, 2264, 1996, 6368]
# 2  [1642, 4450, 2611, 4294, 396, 3598, 5405, 82, ...
# 3                           [5505, 4616, 3440, 6368]
# 4          [1067, 521, 5186, 5525, 2495, 1996, 6368]
#
#                                         DstSentInput  \
# 0  [1, 1125, 6765, 5109, 4861, 2264, 1753, 7005, ...
# 1      [1, 1125, 6765, 5109, 4861, 2264, 1996, 6368]
# 2  [1, 1642, 4450, 2611, 4294, 396, 3598, 5405, 8...
# 3                        [1, 5505, 4616, 3440, 6368]
# 4       [1, 1067, 521, 5186, 5525, 2495, 1996, 6368]
#
#                                         DstSentLabel
# 0  [1125, 6765, 5109, 4861, 2264, 1753, 7005, 199...
# 1      [1125, 6765, 5109, 4861, 2264, 1996, 6368, 2]
# 2  [1642, 4450, 2611, 4294, 396, 3598, 5405, 82, ...
# 3                        [5505, 4616, 3440, 6368, 2]
# 4       [1067, 521, 5186, 5525, 2495, 1996, 6368, 2]

# %%
data.drop(labels=[data.columns[1]],axis=1,inplace=True)

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                         DstSentInput  \
# 0  [1, 1125, 6765, 5109, 4861, 2264, 1753, 7005, ...
# 1      [1, 1125, 6765, 5109, 4861, 2264, 1996, 6368]
# 2  [1, 1642, 4450, 2611, 4294, 396, 3598, 5405, 8...
# 3                        [1, 5505, 4616, 3440, 6368]
# 4       [1, 1067, 521, 5186, 5525, 2495, 1996, 6368]
#
#                                         DstSentLabel
# 0  [1125, 6765, 5109, 4861, 2264, 1753, 7005, 199...
# 1      [1125, 6765, 5109, 4861, 2264, 1996, 6368, 2]
# 2  [1642, 4450, 2611, 4294, 396, 3598, 5405, 82, ...
# 3                        [5505, 4616, 3440, 6368, 2]
# 4       [1067, 521, 5186, 5525, 2495, 1996, 6368, 2]

# %%
data.columns
# Out:
# Index(['SrcSent', 'DstSentInput', 'DstSentLabel'], dtype='object')

# %%
X=list(data["SrcSent"])
Y_input=list(data["DstSentInput"])
Y_label=list(data["DstSentLabel"])

# %%
X_tensor=[torch.tensor(tokenised_eng_sent_ids) for tokenised_eng_sent_ids in X]
Y_input_tensor=[torch.tensor(tokenised_hin_sent_ids) for tokenised_hin_sent_ids in Y_input]
Y_label_tensor=[torch.tensor(tokenised_hin_sent_ids) for tokenised_hin_sent_ids in Y_label]

# %%
X_padded=torch.nn.utils.rnn.pad_sequence(X_tensor,batch_first=True)
Y_padded_input=torch.nn.utils.rnn.pad_sequence(Y_input_tensor,batch_first=True)
Y_padded_label=torch.nn.utils.rnn.pad_sequence(Y_label_tensor,batch_first=True)

# %%
Ns=X_padded.shape[1]
Nd=Y_padded_label.shape[1]

# %%
Ns
# Out:
# 68

# %%
Nd
# Out:
# 68

# %%
class Encoder(torch.nn.Module):

    def __init__(self,src_lang_lang_vocab_size,word_embedding_dim):
        super(Encoder,self).__init__()
        self.first_embedding_layer=torch.nn.Embedding(num_embeddings = src_lang_vocab_size,
                                                      embedding_dim = word_embedding_dim)
        self.second_lstm_layer=torch.nn.LSTM(input_size=word_embedding_dim,
                                             hidden_size=word_embedding_dim,
                                             batch_first=True)
    def forward(self,X_padded_mini_batch):

        first_embedding_layer_out=self.first_embedding_layer(X_padded_mini_batch)
        encoder_output, (final_encoder_output,final_cell_state) = self.second_lstm_layer(first_embedding_layer_out)
        
        return encoder_output,(final_encoder_output,final_cell_state)

# %%
class Decoder(torch.nn.Module):
    
    def __init__(self,dst_lang_vocab_size,word_embedding_dim):
        super(Decoder,self).__init__()
        
        self.first_embedding_layer+torch.nn.Embedding(num_embeddings = src_lang_vocab_size,
                                                      embedding_dim = word_embedding_dim)
        self.second_lstm_layer=torch.nn.LSTM(input_size=word_embedding_dim,
                                             hidden_size=word_embedding_dim,
                                             batch_first=True)
        self.prediction_layer=torch.nn.Linear(in_features=word_embedding_dim,out_features=dst_lang_vocab_size)
        self.prediction_layer_activation=torch.nn.Softmax(dim=2)
        
        
    def forward(self,Y_padded_input_mini_batch,final_encoder_output,final_cell_state):

        first_embedding_layer_out=self.first_embedding_layer(Y_padded_input_mini_batch)
        decoder_lstm_layer_out, (final_decoder_lstm_layer_out,final_cell_state) = self.second_lstm_layer(first_embedding_layer_out,
                                                                                                     final_encoder_output,
                                                                                                      final_cell_state)
        prediction=self.prediction_layer_activation(self.prediction(decoder_lstm_layer_out))
        return prediction, (final_decoder_lstm_layer_out,final_cell_state)
